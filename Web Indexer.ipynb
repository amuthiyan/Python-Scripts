# %%
import nltk
nltk.download('stopwords','tokenizers')
# Out:
# [nltk_data] Downloading package stopwords to tokenizers...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import types
import time
import re
import queue
import string
import os
import glob
from nltk.corpus import stopwords
import nltk
import string

# %%
#Strip the words in doc of any characters that are not alphabets
def makeVal(word):
    word = word.strip(string.punctuation)
    regex=re.compile('[^a-zA-Z]')
    regex.sub('',word)
    word = word.split()
    out_word=''
    for letter in word:
        if letter.isalpha():
            out_word = out_word+letter
    return out_word

# %%
def getPosToken(file):
    #return list of words in the file, remove the duplicates, remove stop words
    return None

# %%
#return list of words in the file, don't remove the duplicates, remove stop words
def getFreqToken(filename):
    file = open(filename,'r')
    html = file.read()
    soup = BeautifulSoup(html,'lxml')
    #text = soup.find_all('p')
    doc = ''
    for para in soup.find_all('p'):
        para = para.find_all(text=True)
        text = ''
        for line in para:
            text = text+line+' '
        #text = text.split(' ')
        #print(text)
        doc = doc+text+' '
    doc = doc.lower()
    doc = doc.split(' ')
    tokens = []
    for word in doc:
        word = makeVal(word)
        if word not in stopwords.words('english') and len(word)>1 and word != 'html':
            tokens.append(word)
    return tokens

# %%
def getUniqueList(inv_index):
    file = open('Unique_Words.txt','w+')
    for word in inv_index:
        file.write(word+"\n")
    file.close()

# %%
def freqIndex(folder):
    #Create the index storage dictionary
    inv_index = {}
    doc_num = 0
    #Create temp dictionary
    #d_freq = {}
    #Read all the files in the crawled pages folder
    path = folder + '/'
    print(path)
    for filename in glob.glob(os.path.join(path,'*.html')):
        print(filename)
        doc_num += 1
        d_freq = {}
        #Convert the file to a list of tokens, or words
        tokens = getFreqToken(filename)
        for word in tokens:
            if word not in d_freq:
                #add the word to the dictionary as a key, with value 0
                #inv_index[word] = []
                #word_count+=1
                d_freq[word]=1
            else:
                #increment the value of the word in dictionary by 1
                #word_count+=1
                d_freq[word]+=1
        #write the values of d_temp to inv_index
        for word in d_freq:
            value = [doc_num,d_freq[word]]
            if word not in inv_index:
                inv_index[word] = []
                inv_index[word].append(value)
            else:
                inv_index[word].append(value)
    num_uni_words = len(inv_index)
    #Write the inverted index to file
    file = open('Inverted Index.txt','w+')
    for word in inv_index:
        file.write(word + ' : ')
        file.write(str(tuple(inv_index[word])))
        file.write('\n')
    file.close()
    getUniqueList(inv_index)
    print('All done!')
freqIndex('Crawled_Pages')
# Out:
# Crawled_Pages/
# Crawled_Pages\1748_English_cricket_season.html
# Crawled_Pages\1876-77_Australian_cricket_season.html
# Crawled_Pages\1912_Triangular_Tournament.html
# Crawled_Pages\1962_English_cricket_season.html
# Crawled_Pages\1963_English_cricket_season.html
# Crawled_Pages\1969_English_cricket_season.html
# Crawled_Pages\1975_Cricket_World_Cup.html
# Crawled_Pages\1975_Cricket_World_Cup_Final.html
# Crawled_Pages\1975_Cricket_World_Cup_squads.html
# Crawled_Pages\1975_Cricket_World_Cup_statistics.html
# Crawled_Pages\1975_ICC_Cricket_World_Cup.html
# Crawled_Pages\1979_Cricket_World_Cup.html
# Crawled_Pages\1979_Cricket_World_Cup_Final.html
# Crawled_Pages\1979_Cricket_World_Cup_squads.html
# Crawled_Pages\1979_Cricket_World_Cup_statistics.html
# Crawled_Pages\1979_ICC_Cricket_World_Cup.html
# Crawled_Pages\1979_ICC_Trophy.html
# Crawled_Pages\1982_ICC_Trophy.html
# Crawled_Pages\1983_Cricket_World_Cup.html
# Crawled_Pages\1983_Cricket_World_Cup_Final.html
# Crawled_Pages\1983_Cricket_World_Cup_squads.html
# Crawled_Pages\1983_Cricket_World_Cup_statistics.html
# Crawled_Pages\1983_ICC_Cricket_World_Cup.html
# Crawled_Pages\1986_ICC_Trophy.html
# Crawled_Pages\1987_Cricket_World_Cup.html
# Crawled_Pages\1987_Cricket_World_Cup_Final.html
# Crawled_Pages\1987_Cricket_World_Cup_squads.html
# Crawled_Pages\1987_Cricket_World_Cup_statistics.html
# Crawled_Pages\1987_ICC_Cricket_World_Cup.html
# Crawled_Pages\1990_ICC_Trophy.html
# Crawled_Pages\1992_Cricket_World_Cup.html
# Crawled_Pages\1992_Cricket_World_Cup_Final.html
# Crawled_Pages\1992_Cricket_World_Cup_squads.html
# Crawled_Pages\1992_Cricket_World_Cup_statistics.html
# Crawled_Pages\1992_ICC_Cricket_World_Cup.html
# Crawled_Pages\1994_ICC_Trophy.html
# Crawled_Pages\1996_Cricket_World_Cup.html
# Crawled_Pages\1996_Cricket_World_Cup_Final.html
# Crawled_Pages\1996_Cricket_World_Cup_squads.html
# Crawled_Pages\1996_Cricket_World_Cup_statistics.html
# Crawled_Pages\1996_ICC_Cricket_World_Cup.html
# Crawled_Pages\1997_ICC_Trophy.html
# Crawled_Pages\1999_Cricket_World_Cup.html
# Crawled_Pages\1999_Cricket_World_Cup_Final.html
# Crawled_Pages\1999_Cricket_World_Cup_squads.html
# Crawled_Pages\1999_Cricket_World_Cup_statistics.html
# Crawled_Pages\1999_ICC_Cricket_World_Cup.html
# Crawled_Pages\2001_ICC_Trophy.html
# Crawled_Pages\2003_Cricket_World_Cup.html
# Crawled_Pages\2003_Cricket_World_Cup_Final.html
# Crawled_Pages\2003_Cricket_World_Cup_squads.html
# Crawled_Pages\2003_Cricket_World_Cup_statistics.html
# Crawled_Pages\2003_ICC_Cricket_World_Cup.html
# Crawled_Pages\2005_ICC_Trophy.html
# Crawled_Pages\2007_Cricket_World_Cup.html
# Crawled_Pages\2007_Cricket_World_Cup_Final.html
# Crawled_Pages\2007_Cricket_World_Cup_squads.html
# Crawled_Pages\2007_Cricket_World_Cup_statistics.html
# Crawled_Pages\2007_ICC_Cricket_World_Cup.html
# Crawled_Pages\2007_ICC_World_Twenty20.html
# Crawled_Pages\2009_attack_on_the_Sri_Lanka_national_cricket_team.html
# Crawled_Pages\2009_Cricket_World_Cup_Qualifier.html
# Crawled_Pages\2010_Commonwealth_Games.html
# Crawled_Pages\2011%E2%80%9313_ICC_World_Cricket_League_Championship.html
# Crawled_Pages\2011_Cricket_World_Cup.html
# Crawled_Pages\2011_Cricket_World_Cup_final.html
# Crawled_Pages\2011_Cricket_World_Cup_squads.html
# Crawled_Pages\2011_Cricket_World_Cup_statistics.html
# Crawled_Pages\2011_ICC_World_Cricket_League_Division_Two.html
# Crawled_Pages\2013_ICC_World_Cricket_League_Division_Three.html
# Crawled_Pages\2014_Commonwealth_Games.html
# Crawled_Pages\2014_Cricket_World_Cup_Qualifier.html
# Crawled_Pages\2014_ICC_World_Cricket_League_Division_Four.html
# Crawled_Pages\2014_ICC_World_Cricket_League_Division_Three.html
# Crawled_Pages\2015%E2%80%9317_ICC_World_Cricket_League_Championship.html
# Crawled_Pages\2015_Cricket_World_Cup.html
# Crawled_Pages\2015_Cricket_World_Cup_Final.html
# Crawled_Pages\2015_Cricket_World_Cup_squads.html
# Crawled_Pages\2015_Cricket_World_Cup_statistics.html
# Crawled_Pages\2015_ICC_World_Cricket_League_Division_Two.html
# Crawled_Pages\2016_ICC_World_Twenty20.html
# Crawled_Pages\2018_Commonwealth_Games.html
# Crawled_Pages\2018_Cricket_World_Cup_Qualifier.html
# Crawled_Pages\2019_Cricket_World_Cup.html
# Crawled_Pages\2023_Cricket_World_Cup.html
# Crawled_Pages\2024_Summer_Olympics.html
# Crawled_Pages\3x3_(basketball).html
# Crawled_Pages\AB_de_Villiers.html
# Crawled_Pages\ACC_Premier_League.html
# Crawled_Pages\ACC_Trophy.html
# Crawled_Pages\ACC_Twenty20_Cup.html
# Crawled_Pages\Adam_Gilchrist.html
# Crawled_Pages\Afghanistan_Cricket_Board.html
# Crawled_Pages\Afghanistan_national_cricket_team.html
# Crawled_Pages\African_Cricket_Association.html
# Crawled_Pages\Airsoft.html
# Crawled_Pages\Ajantha_Mendis.html
# Crawled_Pages\All-rounder.html
# Crawled_Pages\Allan_Donald.html
# Crawled_Pages\American_flag_rugby.html
# Crawled_Pages\American_football.html
# Crawled_Pages\AMF_World_Cup.html
# Crawled_Pages\Amputee_football.html
# Crawled_Pages\Andy_Roberts_(cricketer).html
# Crawled_Pages\Apartheid.html
# Crawled_Pages\Aravinda_de_Silva.html
# Crawled_Pages\Archery_World_Cup.html
# Crawled_Pages\Arena_football.html
# Crawled_Pages\Artillery_Ground.html
# Crawled_Pages\Artistic_Gymnastics_World_Cup.html
# Crawled_Pages\Asian_Cricket_Council.html
# Crawled_Pages\Asian_Test_Championship.html
# Crawled_Pages\Asia_Cup.html
# Crawled_Pages\Association_football.html
# Crawled_Pages\Australia.html
# Crawled_Pages\Australian_football.html
# Crawled_Pages\Australian_Football_International_Cup.html
# Crawled_Pages\Australian_rules_football.html
# Crawled_Pages\Australia_national_cricket_team.html
# Crawled_Pages\Austus.html
# Crawled_Pages\Auto_polo.html
# Crawled_Pages\Backyard_cricket.html
# Crawled_Pages\Ball_badminton.html
# Crawled_Pages\Ball_hockey.html
# Crawled_Pages\Ball_tampering.html
# Crawled_Pages\Bando_(sport).html
# Crawled_Pages\Bandy.html
# Crawled_Pages\Bandy_World_Championship.html
# Crawled_Pages\Bandy_World_Cup.html
# Crawled_Pages\Bandy_World_Cup_Women.html
# Crawled_Pages\Bangladesh.html
# Crawled_Pages\Bangladesh_Cricket_Board.html
# Crawled_Pages\Bangladesh_national_cricket_team.html
# Crawled_Pages\Barbados.html
# Crawled_Pages\Baseball.html
# Crawled_Pages\Basketball.html
# Crawled_Pages\Basque_pelota.html
# Crawled_Pages\Bat-and-ball_game.html
# Crawled_Pages\Bat-and-ball_games.html
# Crawled_Pages\Batsman.html
# Crawled_Pages\Batsmen.html
# Crawled_Pages\Batting_(cricket).html
# Crawled_Pages\Batting_average.html
# Crawled_Pages\Batting_gloves.html
# Crawled_Pages\Batting_order_(cricket).html
# Crawled_Pages\Batting_pads.html
# Crawled_Pages\Ba_game.html
# Crawled_Pages\BDO_World_Darts_Championship.html
# Crawled_Pages\Beach_basketball.html
# Crawled_Pages\Beach_cricket.html
# Crawled_Pages\Beach_handball.html
# Crawled_Pages\Beach_rugby.html
# Crawled_Pages\Beach_soccer.html
# Crawled_Pages\Bermuda_national_cricket_team.html
# Crawled_Pages\Beyond_a_Boundary.html
# Crawled_Pages\Biathlon_World_Championships.html
# Crawled_Pages\Biathlon_World_Cup.html
# Crawled_Pages\Biribol.html
# Crawled_Pages\Birmingham.html
# Crawled_Pages\Blind_Cricket.html
# Crawled_Pages\Board_of_Control_for_Cricket_in_India.html
# Crawled_Pages\Bobsleigh_World_Cup.html
# Crawled_Pages\Bob_Woolmer.html
# Crawled_Pages\Boccia.html
# Crawled_Pages\Border-Gavaskar_Trophy.html
# Crawled_Pages\Bossaball.html
# Crawled_Pages\Bouncing_ball.html
# Crawled_Pages\Boundary_(cricket).html
# Crawled_Pages\Bowled.html
# Crawled_Pages\Bowler_(cricket).html
# Crawled_Pages\Bowling_(cricket).html
# Crawled_Pages\Bowling_average.html
# Crawled_Pages\Bowls.html
# Crawled_Pages\Boxing_World_Cup.html
# Crawled_Pages\Box_(cricket).html
# Crawled_Pages\Box_lacrosse.html
# Crawled_Pages\Br%C3%A4nnboll.html
# Crawled_Pages\Brian_Lara.html
# Crawled_Pages\British_baseball.html
# Crawled_Pages\Broomball.html
# Crawled_Pages\Buzkashi.html
# Crawled_Pages\C.html
# Crawled_Pages\Caid_(sport).html
# Crawled_Pages\Calcio_Fiorentino.html
# Crawled_Pages\Cammag.html
# Crawled_Pages\Camogie.html
# Crawled_Pages\Camping_(game).html
# Crawled_Pages\Canada_national_cricket_team.html
# Crawled_Pages\Canadian_cricket_team.html
# Crawled_Pages\Canadian_football.html
# Crawled_Pages\Canoe_polo.html
# Crawled_Pages\Canoe_Slalom_World_Cup.html
# Crawled_Pages\Captain_(cricket).html
# Crawled_Pages\Caught.html
# Crawled_Pages\Caught_(cricket).html
# Crawled_Pages\Century_(cricket).html
# Crawled_Pages\Cestoball.html
# Crawled_Pages\Champion_County.html
# Crawled_Pages\Chess_World_Cup.html
# Crawled_Pages\Chris_Gayle.html
# Crawled_Pages\Circle_rules_football.html
# Crawled_Pages\Class_1_World_Powerboat_Championship.html
# Crawled_Pages\Clive_Lloyd.html
# Crawled_Pages\Club_cricket.html
# Crawled_Pages\Cnapan.html
# Crawled_Pages\Colin_Cowdrey.html
# Crawled_Pages\Comparison_of_cricket_and_baseball.html
# Crawled_Pages\Composite_rules_shinty-hurling.html
# Crawled_Pages\Cork_(material).html
# Crawled_Pages\Cornish_hurling.html
# Crawled_Pages\County_Championship.html
# Crawled_Pages\County_cricket.html
# Crawled_Pages\Cowboy_polo.html
# Crawled_Pages\Crease_(cricket).html
# Crawled_Pages\Cricinfo.html
# Crawled_Pages\Cricket.html
# Crawled_Pages\Cricket_at_the_1900_Summer_Olympics.html
# Crawled_Pages\Cricket_at_the_1998_Commonwealth_Games.html
# Crawled_Pages\Cricket_at_the_2003_South_Pacific_Games.html
# Crawled_Pages\Cricket_at_the_2007_South_Pacific_Games.html
# Crawled_Pages\Cricket_at_the_2010_Asian_Games.html
# Crawled_Pages\Cricket_at_the_2010_South_Asian_Games.html
# Crawled_Pages\Cricket_at_the_2011_Pacific_Games.html
# Crawled_Pages\Cricket_at_the_Asian_Games.html
# Crawled_Pages\Cricket_at_the_Pacific_Games.html
# Crawled_Pages\Cricket_at_the_South_Asian_Games.html
# Crawled_Pages\Cricket_Australia.html
# Crawled_Pages\Cricket_ball.html
# Crawled_Pages\Cricket_bat.html
# Crawled_Pages\Cricket_Canada.html
# Crawled_Pages\Cricket_captain.html
# Crawled_Pages\Cricket_clothing_and_equipment.html
# Crawled_Pages\Cricket_field.html
# Crawled_Pages\Cricket_in_fiction.html
# Crawled_Pages\Cricket_Ireland.html
# Crawled_Pages\Cricket_Kenya.html
# Crawled_Pages\Cricket_pitch.html
# Crawled_Pages\Cricket_Scotland.html
# Crawled_Pages\Cricket_South_Africa.html
# Crawled_Pages\Cricket_statistics.html
# Crawled_Pages\Cricket_World_Cup.html
# Crawled_Pages\Cricket_World_Cup_awards.html
# Crawled_Pages\Cricket_World_Cup_hosts.html
# Crawled_Pages\Cricket_World_Cup_qualification.html
# Crawled_Pages\Cricket_World_Cup_Qualifier.html
# Crawled_Pages\Cricket_World_Cup_teams.html
# Crawled_Pages\Cricket_World_Cup_Trophy.html
# Crawled_Pages\Cuju.html
# Crawled_Pages\Curling.html
# Crawled_Pages\Currie_Cup.html
# Crawled_Pages\Cycle_ball.html
# Crawled_Pages\Cycle_polo.html
# Crawled_Pages\Czech_handball.html
# Crawled_Pages\Danish_longball.html
# Crawled_Pages\Dave_Richardson_(cricketer).html
# Crawled_Pages\David_Boon.html
# Crawled_Pages\Davis_Cup.html
# Crawled_Pages\Deaf_basketball.html
# Crawled_Pages\Declaration_(cricket).html
# Crawled_Pages\Declaration_and_forfeiture.html
# Crawled_Pages\Delhi.html
# Crawled_Pages\Delivery_(cricket).html
# Crawled_Pages\Dismissal_(cricket).html
# Crawled_Pages\Dodgeball.html
# Crawled_Pages\Donald_Bradman.html
# Crawled_Pages\Don_Bradman.html
# Crawled_Pages\Draw_(cricket).html
# Crawled_Pages\Dressage_World_Cup.html
# Crawled_Pages\Dubai.html
# Crawled_Pages\Duckworth-Lewis_method.html
# Crawled_Pages\East_African_cricket_team.html
# Crawled_Pages\East_Africa_cricket_team.html
# Crawled_Pages\Economy_rate.html
# Crawled_Pages\Eden_Gardens.html
# Crawled_Pages\Edge_(cricket).html
# Crawled_Pages\Eight-man_football.html
# Crawled_Pages\Elephant_polo.html
# Crawled_Pages\Endurance_FIM_World_Championship.html
# Crawled_Pages\England.html
# Crawled_Pages\England_and_Wales_Cricket_Board.html
# Crawled_Pages\England_cricket_team.html
# Crawled_Pages\England_national_cricket_team.html
# Crawled_Pages\English_cricket_team_in_Australia_in_1970%E2%80%9371.html
# Crawled_Pages\ESPNcricinfo.html
# Crawled_Pages\ESports.html
# Crawled_Pages\Estonia.html
# Crawled_Pages\European_Cricket_Championship.html
# Crawled_Pages\European_Cricket_Council.html
# Crawled_Pages\Extra_(cricket).html
# Crawled_Pages\FAI_World_Aerobatic_Championships.html
# Crawled_Pages\Fast5.html
# Crawled_Pages\Fastpitch_softball.html
# Crawled_Pages\Fed_Cup.html
# Crawled_Pages\FEI_World_Equestrian_Games.html
# Crawled_Pages\FIA_Formula_E_Championship.html
# Crawled_Pages\FIA_World_Endurance_Championship.html
# Crawled_Pages\FIA_World_Rallycross_Championship.html
# Crawled_Pages\FIBA_Basketball_World_Cup.html
# Crawled_Pages\FIBA_Women%27s_Basketball_World_Cup.html
# Crawled_Pages\FIBT_World_Championships.html
# Crawled_Pages\Fielding_(cricket).html
# Crawled_Pages\Fielding_positions_in_cricket.html
# Crawled_Pages\Fielding_restrictions_(cricket).html
# Crawled_Pages\Field_handball.html
# Crawled_Pages\Field_hockey.html
# Crawled_Pages\Field_lacrosse.html
# Crawled_Pages\FIFA_Beach_Soccer_World_Cup.html
# Crawled_Pages\FIFA_Club_World_Cup.html
# Crawled_Pages\FIFA_Futsal_World_Cup.html
# Crawled_Pages\FIFA_Interactive_World_Cup.html
# Crawled_Pages\FIFA_Women%27s_Club_World_Cup.html
# Crawled_Pages\FIFA_Women%27s_World_Cup.html
# Crawled_Pages\FIFA_World_Cup.html
# Crawled_Pages\FIL_World_Luge_Championships.html
# Crawled_Pages\FINA_Diving_World_Cup.html
# Crawled_Pages\FINA_Swimming_World_Cup.html
# Crawled_Pages\FINA_Water_Polo_World_Cup.html
# Crawled_Pages\FINA_Women%27s_Water_Polo_World_Cup.html
# Crawled_Pages\FINA_World_Aquatics_Championships.html
# Crawled_Pages\FINA_World_Swimming_Championships_(25_m).html
# Crawled_Pages\First-class_cricket.html
# Crawled_Pages\FIRS_Roller_Hockey_World_Cup.html
# Crawled_Pages\Fistball.html
# Crawled_Pages\FIS_Alpine_Ski_World_Cup.html
# Crawled_Pages\FIS_Alpine_World_Ski_Championships.html
# Crawled_Pages\FIS_Cross-Country_World_Cup.html
# Crawled_Pages\FIS_Freestyle_Skiing_World_Cup.html
# Crawled_Pages\FIS_Freestyle_World_Ski_Championships.html
# Crawled_Pages\FIS_Nordic_Combined_World_Cup.html
# Crawled_Pages\FIS_Ski_Flying_World_Cup.html
# Crawled_Pages\FIS_Ski_Jumping_World_Cup.html
# Crawled_Pages\FIS_Snowboard_World_Championships.html
# Crawled_Pages\FIS_Snowboard_World_Cup.html
# Crawled_Pages\FIVB_Volleyball_Men%27s_World_Championship.html
# Crawled_Pages\FIVB_Volleyball_Women%27s_World_Championship.html
# Crawled_Pages\Floorball.html
# Crawled_Pages\Floor_hockey.html
# Crawled_Pages\Footbag_net.html
# Crawled_Pages\Football.html
# Crawled_Pages\Football_tennis.html
# Crawled_Pages\Footvolley.html
# Crawled_Pages\Forms_of_cricket.html
# Crawled_Pages\Formula_1_Powerboat_World_Championship.html
# Crawled_Pages\Formula_One.html
# Crawled_Pages\Frank_Worrell_Trophy.html
# Crawled_Pages\Fred_Lillywhite.html
# Crawled_Pages\Freestyle_football.html
# Crawled_Pages\French_cricket.html
# Crawled_Pages\Friends_Provident_Trophy.html
# Crawled_Pages\Frontenis.html
# Crawled_Pages\Futsal.html
# Crawled_Pages\Gaddafi_Stadium.html
# Crawled_Pages\Gaelic_football.html
# Crawled_Pages\Garden_cricket.html
# Crawled_Pages\Gateball.html
# Crawled_Pages\Gillette_Cup_(England).html
# Crawled_Pages\Glenn_McGrath.html
# Crawled_Pages\Goalball.html
# Crawled_Pages\Golden_Age_of_cricket.html
# Crawled_Pages\Googly.html
# Crawled_Pages\Grand_Prix_motorcycle_racing.html
# Crawled_Pages\Gridiron_football.html
# Crawled_Pages\Guildford.html
# Crawled_Pages\Guinness_World_Records.html
# Crawled_Pages\Gulf_News.html
# Crawled_Pages\Guyana.html
# Crawled_Pages\Handball.html
# Crawled_Pages\Handled_the_ball.html
# Crawled_Pages\Harpastum.html
# Crawled_Pages\Harry_Altham.html
# Crawled_Pages\Hawk-Eye.html
# Crawled_Pages\Helmet_(cricket).html
# Crawled_Pages\Henry_Chadwick_(writer).html
# Crawled_Pages\History_of_cricket.html
# Crawled_Pages\History_of_the_Cricket_World_Cup.html
# Crawled_Pages\Hit_wicket.html
# Crawled_Pages\Hockey.html
# Crawled_Pages\Hockey_World_Cup_(field_hockey).html
# Crawled_Pages\Hopman_Cup.html
# Crawled_Pages\Horseball.html
# Crawled_Pages\Hot_Spot_(cricket).html
# Crawled_Pages\Hurling.html
# Crawled_Pages\IAAF_Continental_Cup.html
# Crawled_Pages\IAAF_World_Half_Marathon_Championships.html
# Crawled_Pages\IAAF_World_Race_Walking_Cup.html
# Crawled_Pages\Icc.html
# Crawled_Pages\ICC_Americas.html
# Crawled_Pages\ICC_Americas_Championship.html
# Crawled_Pages\ICC_associate_membership.html
# Crawled_Pages\ICC_Awards.html
# Crawled_Pages\ICC_Champions_Trophy.html
# Crawled_Pages\ICC_Cricket_World_Cup.html
# Crawled_Pages\ICC_East_Asia-Pacific.html
# Crawled_Pages\ICC_Intercontinental_Cup.html
# Crawled_Pages\ICC_ODI_Championship.html
# Crawled_Pages\ICC_Player_Rankings.html
# Crawled_Pages\ICC_T20_Championship.html
# Crawled_Pages\ICC_Test_Championship.html
# Crawled_Pages\ICC_Trophy.html
# Crawled_Pages\ICC_Under-19_Cricket_World_Cup.html
# Crawled_Pages\ICC_Women%27s_World_Twenty20.html
# Crawled_Pages\ICC_Women%27s_World_Twenty20_Qualifier.html
# Crawled_Pages\ICC_World_Cup_Qualifier.html
# Crawled_Pages\ICC_World_Test_Championship.html
# Crawled_Pages\ICC_World_Twenty20.html
# Crawled_Pages\ICC_World_Twenty20_Qualifier.html
# Crawled_Pages\Ice_hockey.html
# Crawled_Pages\Ice_Hockey_World_Championships.html
# Crawled_Pages\IFAF_Flag_Football_World_Championship.html
# Crawled_Pages\IFAF_Women%27s_World_Championship.html
# Crawled_Pages\IFAF_World_Championship.html
# Crawled_Pages\IFSC_Climbing_World_Championships.html
# Crawled_Pages\IHF_World_Men%27s_Handball_Championship.html
# Crawled_Pages\IHF_World_Women%27s_Handball_Championship.html
# Crawled_Pages\IIHF_World_Women%27s_Championships.html
# Crawled_Pages\IKF_World_Korfball_Championship.html
# Crawled_Pages\index.html
# Crawled_Pages\India.html
# Crawled_Pages\Indian_Cricket_League.html
# Crawled_Pages\Indian_national_cricket_team.html
# Crawled_Pages\Indian_Premier_League.html
# Crawled_Pages\India_national_cricket_team.html
# Crawled_Pages\Indoor_American_football.html
# Crawled_Pages\Indoor_cricket.html
# Crawled_Pages\Indoor_cricket_(UK_variant).html
# Crawled_Pages\Indoor_Cricket_World_Cup.html
# Crawled_Pages\Indoor_field_hockey.html
# Crawled_Pages\Indoor_netball.html
# Crawled_Pages\Indoor_soccer.html
# Crawled_Pages\Inner_tube_water_polo.html
# Crawled_Pages\Innings.html
# Crawled_Pages\Intercontinental_Futsal_Cup.html
# Crawled_Pages\Intercrosse.html
# Crawled_Pages\International_cricket.html
# Crawled_Pages\International_Cricket_Council.html
# Crawled_Pages\International_rules_football.html
# Crawled_Pages\International_structure_of_cricket.html
# Crawled_Pages\Iomain.html
# Crawled_Pages\Ireland_cricket_team.html
# Crawled_Pages\ISAF_Sailing_World_Cup.html
# Crawled_Pages\ISSF_World_Cup.html
# Crawled_Pages\ISSF_World_Shooting_Championships.html
# Crawled_Pages\ISU_Short_Track_Speed_Skating_World_Cup.html
# Crawled_Pages\ISU_Speed_Skating_World_Cup.html
# Crawled_Pages\ITU_Triathlon_World_Cup.html
# Crawled_Pages\Jai_alai.html
# Crawled_Pages\Jamaica.html
# Crawled_Pages\James_Faulkner_(cricketer).html
# Crawled_Pages\Jianzi.html
# Crawled_Pages\John_Major.html
# Crawled_Pages\Jokgu.html
# Crawled_Pages\Jorkyball.html
# Crawled_Pages\Kabaddi.html
# Crawled_Pages\Kemari.html
# Crawled_Pages\Kennington_Oval.html
# Crawled_Pages\Kensington_Oval.html
# Crawled_Pages\Kenya.html
# Crawled_Pages\Kenya_national_cricket_team.html
# Crawled_Pages\Kerry_Packer.html
# Crawled_Pages\Kho_kho.html
# Crawled_Pages\Ki-o-rahi.html
# Crawled_Pages\Kickball.html
# Crawled_Pages\Kilikiti.html
# Crawled_Pages\Knattleikr.html
# Crawled_Pages\Knotty.html
# Crawled_Pages\Koninklijke_Nederlandse_Cricket_Bond.html
# Crawled_Pages\Korfball.html
# Crawled_Pages\Kumar_Sangakkara.html
# Crawled_Pages\Kwik_cricket.html
# Crawled_Pages\Lacrosse.html
# Crawled_Pages\Ladies%27_Gaelic_football.html
# Crawled_Pages\Lagori.html
# Crawled_Pages\Lahore.html
# Crawled_Pages\Lance_Klusener.html
# Crawled_Pages\Lapta_(game).html
# Crawled_Pages\Lasith_Malinga.html
# Crawled_Pages\Lawn.html
# Crawled_Pages\Laws_of_cricket.html
# Crawled_Pages\La_soule.html
# Crawled_Pages\League_of_Legends_World_Championship.html
# Crawled_Pages\Left-handed.html
# Crawled_Pages\Leg_before_wicket.html
# Crawled_Pages\Leg_break.html
# Crawled_Pages\Lelo_burti.html
# Crawled_Pages\Lightning_football.html
# Crawled_Pages\Limited_overs_cricket.html
# Crawled_Pages\Limited_Overs_International.html
# Crawled_Pages\Lists_of_cricket_records.html
# Crawled_Pages\Lists_of_sportspeople.html
# Crawled_Pages\List_A_cricket.html
# Crawled_Pages\List_of_cricket_terms.html
# Crawled_Pages\List_of_Cricket_World_Cup_centuries.html
# Crawled_Pages\List_of_Cricket_World_Cup_finals.html
# Crawled_Pages\List_of_Cricket_World_Cup_five-wicket_hauls.html
# Crawled_Pages\List_of_Cricket_World_Cup_records.html
# Crawled_Pages\List_of_current_female_world_boxing_champions.html
# Crawled_Pages\List_of_current_world_boxing_champions.html
# Crawled_Pages\List_of_ICC_Cricket_World_Cup_finals.html
# Crawled_Pages\List_of_International_Cricket_Council_members.html
# Crawled_Pages\List_of_One_Day_International_cricket_records.html
# Crawled_Pages\List_of_Test_cricket_records.html
# Crawled_Pages\List_of_Twenty20_International_records.html
# Crawled_Pages\List_of_World_Backgammon_champions.html
# Crawled_Pages\List_of_world_championships_medalists_in_powerlifting_(men).html
# Crawled_Pages\List_of_world_sports_championships.html
# Crawled_Pages\Lord%27s.html
# Crawled_Pages\Lord%27s_Cricket_Ground.html
# Crawled_Pages\Luge_World_Cup.html
# Crawled_Pages\M.html
# Crawled_Pages\Macau_Grand_Prix.html
# Crawled_Pages\Mahendra_Singh_Dhoni.html
# Crawled_Pages\Man_of_the_Match.html
# Crawled_Pages\Marlon_Samuels.html
# Crawled_Pages\Marn_Grook.html
# Crawled_Pages\Martin_Crowe.html
# Crawled_Pages\Martin_Guptill.html
# Crawled_Pages\Marylebone_Cricket_Club.html
# Crawled_Pages\Masters_Rugby_League.html
# Crawled_Pages\Matball.html
# Crawled_Pages\Match_referee_(Cricket).html
# Crawled_Pages\Medieval_football.html
# Crawled_Pages\Melbourne_Cricket_Ground.html
# Crawled_Pages\Men%27s_Roller_Derby_World_Cup.html
# Crawled_Pages\Men%27s_Softball_World_Championship.html
# Crawled_Pages\Metro_footy.html
# Crawled_Pages\Mini_rugby.html
# Crawled_Pages\Mitchell_Starc.html
# Crawled_Pages\Mod_league.html
# Crawled_Pages\Mohinder_Amarnath.html
# Crawled_Pages\Mongoose.html
# Crawled_Pages\Moscow_broomball.html
# Crawled_Pages\Motocross_des_Nations.html
# Crawled_Pages\Namibian_cricket_team.html
# Crawled_Pages\Namibia_national_cricket_team.html
# Crawled_Pages\National_Baseball_Hall_of_Fame_and_Museum.html
# Crawled_Pages\Netball.html
# Crawled_Pages\Netherlands.html
# Crawled_Pages\Netherlands_national_cricket_team.html
# Crawled_Pages\Net_sport.html
# Crawled_Pages\New_South_Wales_cricket_team.html
# Crawled_Pages\New_Zealand.html
# Crawled_Pages\New_Zealand_Cricket.html
# Crawled_Pages\New_Zealand_national_cricket_team.html
# Crawled_Pages\Night_ODI.html
# Crawled_Pages\Nine-a-side_footy.html
# Crawled_Pages\Nine-man_football.html
# Crawled_Pages\Not_out.html
# Crawled_Pages\No_ball.html
# Crawled_Pages\Obstructing_the_field.html
# Crawled_Pages\Oin%C4%83.html
# Crawled_Pages\Olympic_Games.html
# Crawled_Pages\One-day_International.html
# Crawled_Pages\One_Day_International.html
# Crawled_Pages\One_Day_International_cricket.html
# Crawled_Pages\Orienteering_World_Cup.html
# Crawled_Pages\Over_(cricket).html
# Crawled_Pages\P%C3%A9tanque.html
# Crawled_Pages\P.html
# Crawled_Pages\Paintball.html
# Crawled_Pages\Pakistan.html
# Crawled_Pages\Pakistan_Cricket_Board.html
# Crawled_Pages\Pakistan_national_cricket_team.html
# Crawled_Pages\Paralympic_association_football.html
# Crawled_Pages\Paralympic_Winter_World_Cup.html
# Crawled_Pages\Paralympic_World_Cup.html
# Crawled_Pages\Partnership_(cricket).html
# Crawled_Pages\Pato.html
# Crawled_Pages\PBR_World_Cup.html
# Crawled_Pages\Pes%C3%A4pallo.html
# Crawled_Pages\Peteca.html
# Crawled_Pages\Pitched_delivery_bowling.html
# Crawled_Pages\Pitch_and_Putt_World_Cup.html
# Crawled_Pages\Playing_time_(cricket).html
# Crawled_Pages\Playoff_format.html
# Crawled_Pages\Plunket_Shield.html
# Crawled_Pages\Polocrosse.html
# Crawled_Pages\Pond_hockey.html
# Crawled_Pages\Powerchair_Football.html
# Crawled_Pages\Power_hockey.html
# Crawled_Pages\Quidditch_(sport).html
# Crawled_Pages\Ranji_Trophy.html
# Crawled_Pages\Rec_footy.html
# Crawled_Pages\Red_Bull_Air_Race_World_Championship.html
# Crawled_Pages\Republic_of_Ireland.html
# Crawled_Pages\Result_(cricket).html
# Crawled_Pages\Retired_out.html
# Crawled_Pages\Rhythmic_Gymnastics_World_Cup.html
# Crawled_Pages\Ricky_Ponting.html
# Crawled_Pages\Right-handed.html
# Crawled_Pages\Ringette.html
# Crawled_Pages\Rink_bandy.html
# Crawled_Pages\Ritinis.html
# Crawled_Pages\Rollball.html
# Crawled_Pages\Roller_derby.html
# Crawled_Pages\Roller_Derby_World_Cup.html
# Crawled_Pages\Roller_hockey.html
# Crawled_Pages\Roller_hockey_(quad).html
# Crawled_Pages\Roller_in-line_hockey.html
# Crawled_Pages\Rossall_Hockey.html
# Crawled_Pages\Round-robin_tournament.html
# Crawled_Pages\Roundarm_bowling.html
# Crawled_Pages\Rounders.html
# Crawled_Pages\Rugby_football.html
# Crawled_Pages\Rugby_league.html
# Crawled_Pages\Rugby_league_nines.html
# Crawled_Pages\Rugby_league_sevens.html
# Crawled_Pages\Rugby_League_World_Cup.html
# Crawled_Pages\Rugby_sevens.html
# Crawled_Pages\Rugby_tens.html
# Crawled_Pages\Rugby_union.html
# Crawled_Pages\Rugby_World_Cup.html
# Crawled_Pages\Rugby_World_Cup_Sevens.html
# Crawled_Pages\Runner_(cricket).html
# Crawled_Pages\Run_(cricket).html
# Crawled_Pages\Run_out.html
# Crawled_Pages\Run_rate.html
# Crawled_Pages\Sachin_Tendulkar.html
# Crawled_Pages\Samoa_rules.html
# Crawled_Pages\Sanath_Jayasuriya.html
# Crawled_Pages\Scorer.html
# Crawled_Pages\Scoring_(cricket).html
# Crawled_Pages\Scotland_national_cricket_team.html
# Crawled_Pages\Segway_polo.html
# Crawled_Pages\Sepak_takraw.html
# Crawled_Pages\Shane_Warne.html
# Crawled_Pages\Sheffield_Shield.html
# Crawled_Pages\Shell_Eco-marathon.html
# Crawled_Pages\Shell_Shield.html
# Crawled_Pages\Shinny.html
# Crawled_Pages\Shinty.html
# Crawled_Pages\Shoaib_Akhtar.html
# Crawled_Pages\Short_form_cricket.html
# Crawled_Pages\Show_Jumping_World_Cup.html
# Crawled_Pages\Sidecarcross_World_Championship.html
# Crawled_Pages\Sidecar_World_Championship.html
# Crawled_Pages\Single-elimination_tournament.html
# Crawled_Pages\Single_wicket_cricket.html
# Crawled_Pages\Sitting_volleyball.html
# Crawled_Pages\Six-man_football.html
# Crawled_Pages\Skeleton_World_Cup.html
# Crawled_Pages\Slamball.html
# Crawled_Pages\Sledge_hockey.html
# Crawled_Pages\Sledging_(cricket).html
# Crawled_Pages\Snickometer.html
# Crawled_Pages\Snow_rugby.html
# Crawled_Pages\Softball.html
# Crawled_Pages\South_Africa.html
# Crawled_Pages\South_Africa_national_cricket_team.html
# Crawled_Pages\South_American_Cricket_Championship.html
# Crawled_Pages\Sport.html
# Crawled_Pages\Sporting_boycott_of_South_Africa_during_the_apartheid_era.html
# Crawled_Pages\Sprint_football.html
# Crawled_Pages\Sri_Lanka.html
# Crawled_Pages\Sri_Lankan_national_cricket_team.html
# Crawled_Pages\Sri_Lanka_Cricket.html
# Crawled_Pages\Sri_Lanka_national_cricket_team.html
# Crawled_Pages\Sticky_wicket.html
# Crawled_Pages\Stoolball.html
# Crawled_Pages\Street_cricket.html
# Crawled_Pages\Street_football.html
# Crawled_Pages\Street_hockey.html
# Crawled_Pages\Strike_rate.html
# Crawled_Pages\Stumped.html
# Crawled_Pages\Stumpy_(mascot).html
# Crawled_Pages\Stump_(cricket).html
# Crawled_Pages\Substitute_(cricket).html
# Crawled_Pages\Summer_Olympic_Games.html
# Crawled_Pages\Superbike_World_Championship.html
# Crawled_Pages\Sussex_County_Cricket_Club.html
# Crawled_Pages\Swedish_football_(code).html
# Crawled_Pages\Sydney.html
# Crawled_Pages\Table_Cricket.html
# Crawled_Pages\Tag_rugby.html
# Crawled_Pages\Tape_ball.html
# Crawled_Pages\Tape_ball_cricket.html
# Crawled_Pages\Tchoukball.html
# Crawled_Pages\Team_sport.html
# Crawled_Pages\Tennis_ball_cricket.html
# Crawled_Pages\Test_cricket.html
# Crawled_Pages\The_Ashes.html
# Crawled_Pages\Third_umpire.html
# Crawled_Pages\Thomas_Cup.html
# Crawled_Pages\Throwball.html
# Crawled_Pages\Throwing_(cricket).html
# Crawled_Pages\Timed_out.html
# Crawled_Pages\Tom_Wills.html
# Crawled_Pages\Toss_(cricket).html
# Crawled_Pages\Touch_(sport).html
# Crawled_Pages\Touch_football_(American).html
# Crawled_Pages\Touch_Football_World_Cup.html
# Crawled_Pages\Touch_rugby.html
# Crawled_Pages\Town_ball.html
# Crawled_Pages\Trampoline_World_Championships.html
# Crawled_Pages\Trinidad_%26_Tobago.html
# Crawled_Pages\Trobriand_cricket.html
# Crawled_Pages\Twenty20.html
# Crawled_Pages\Twenty20_Champions_League.html
# Crawled_Pages\Twenty20_International.html
# Crawled_Pages\Twenty20_World_Championship.html
# Crawled_Pages\Types_of_bowlers_in_cricket.html
# Crawled_Pages\Uber_Cup.html
# Crawled_Pages\UCI_BMX_World_Championships.html
# Crawled_Pages\UCI_Cyclo-cross_World_Championships.html
# Crawled_Pages\UCI_Cyclo-cross_World_Cup.html
# Crawled_Pages\UCI_Mountain_Bike_Marathon_World_Championships.html
# Crawled_Pages\UCI_Mountain_Bike_World_Cup.html
# Crawled_Pages\UCI_Road_World_Championships.html
# Crawled_Pages\UCI_Road_World_Cup.html
# Crawled_Pages\UCI_Track_Cycling_World_Championships.html
# Crawled_Pages\UCI_Track_Cycling_World_Cup.html
# Crawled_Pages\UCI_Women%27s_Road_World_Cup.html
# Crawled_Pages\Ulama_(game).html
# Crawled_Pages\Ultimate_(sport).html
# Crawled_Pages\Umpire_(cricket).html
# Crawled_Pages\Umpire_Decision_Review_System.html
# Crawled_Pages\Under-19_Cricket_World_Cup.html
# Crawled_Pages\Underarm_bowling.html
# Crawled_Pages\Underwater_football.html
# Crawled_Pages\Underwater_hockey.html
# Crawled_Pages\Underwater_ice_hockey.html
# Crawled_Pages\Underwater_rugby.html
# Crawled_Pages\Unicycle_hockey.html
# Crawled_Pages\United_Arab_Emirates_national_cricket_team.html
# Crawled_Pages\United_Kingdom.html
# Crawled_Pages\United_States_national_cricket_team.html
# Crawled_Pages\Universal_football.html
# Crawled_Pages\Uppies_and_Downies.html
# Crawled_Pages\Victor_Trumper.html
# Crawled_Pages\Vigoro.html
# Crawled_Pages\Viv_Richards.html
# Crawled_Pages\Volata.html
# Crawled_Pages\Volleyball.html
# Crawled_Pages\W.html
# Crawled_Pages\Wales.html
# Crawled_Pages\Walking_football.html
# Crawled_Pages\Wanderers_Stadium.html
# Crawled_Pages\Wankhede_Stadium.html
# Crawled_Pages\Wasim_Akram.html
# Crawled_Pages\Water_basketball.html
# Crawled_Pages\Water_polo.html
# Crawled_Pages\West_Indies_cricket_team.html
# Crawled_Pages\West_Indies_national_cricket_team.html
# Crawled_Pages\Wheelchair_basketball.html
# Crawled_Pages\Wheelchair_Basketball_World_Championship.html
# Crawled_Pages\Wheelchair_curling.html
# Crawled_Pages\Wheelchair_netball.html
# Crawled_Pages\Wheelchair_rugby.html
# Crawled_Pages\Wheelchair_rugby_league.html
# Crawled_Pages\Whirlyball.html
# Crawled_Pages\Wicket-keeper.html
# Crawled_Pages\Wicket.html
# Crawled_Pages\Wicket_keeper.html
# Crawled_Pages\Wide_(cricket).html
# Crawled_Pages\Wisden_Cricketers%27_Almanack.html
# Crawled_Pages\Wisden_Trophy.html
# Crawled_Pages\Women%27s_Bandy_World_Championship.html
# Crawled_Pages\Women%27s_Baseball_World_Cup.html
# Crawled_Pages\Women%27s_cricket.html
# Crawled_Pages\Women%27s_Cricket_World_Cup.html
# Crawled_Pages\Women%27s_Cricket_World_Cup_Qualifier.html
# Crawled_Pages\Women%27s_European_Cricket_Championship.html
# Crawled_Pages\Women%27s_Hockey_World_Cup.html
# Crawled_Pages\Women%27s_lacrosse.html
# Crawled_Pages\Women%27s_Lacrosse_World_Cup.html
# Crawled_Pages\Women%27s_One_Day_International_cricket.html
# Crawled_Pages\Women%27s_Rugby_League_World_Cup.html
# Crawled_Pages\Women%27s_Rugby_World_Cup.html
# Crawled_Pages\Women%27s_Softball_World_Championship.html
# Crawled_Pages\Women%27s_Test_cricket.html
# Crawled_Pages\Women%27s_Twenty20_International.html
# Crawled_Pages\Women%27s_World_Cup_of_Golf.html
# Crawled_Pages\World_Amateur_Go_Championship.html
# Crawled_Pages\World_Archery_Championships.html
# Crawled_Pages\World_Artistic_Gymnastics_Championships.html
# Crawled_Pages\World_Baseball_Classic.html
# Crawled_Pages\World_Billiards_Championship_(English_billiards).html
# Crawled_Pages\World_Bowls_Events.html
# Crawled_Pages\World_Championships_in_Athletics.html
# Crawled_Pages\World_Chess_Championship.html
# Crawled_Pages\World_Club_Challenge.html
# Crawled_Pages\World_Cricket_League.html
# Crawled_Pages\World_Cup_(men%27s_golf).html
# Crawled_Pages\World_Cup_(snooker).html
# Crawled_Pages\World_Cup_in_Ski_Orienteering.html
# Crawled_Pages\World_Cup_of_Hockey.html
# Crawled_Pages\World_Cup_of_Pool.html
# Crawled_Pages\World_Cup_of_Softball.html
# Crawled_Pages\World_Curling_Championships.html
# Crawled_Pages\World_Enduro_Championship.html
# Crawled_Pages\World_Fencing_Championships.html
# Crawled_Pages\World_Gliding_Championships.html
# Crawled_Pages\World_Gymnastics_Championships.html
# Crawled_Pages\World_Kendo_Championship.html
# Crawled_Pages\World_Open_(squash).html
# Crawled_Pages\World_Polo_Championship.html
# Crawled_Pages\World_Puzzle_Championship.html
# Crawled_Pages\World_Rally_Championship-2.html
# Crawled_Pages\World_Rally_Championship-3.html
# Crawled_Pages\World_Rally_Championship.html
# Crawled_Pages\World_Rhythmic_Gymnastics_Championships.html
# Crawled_Pages\World_Rowing_Cup.html
# Crawled_Pages\World_Scrabble_Championship.html
# Crawled_Pages\World_Series_Cricket.html
# Crawled_Pages\World_Snooker_Championship.html
# Crawled_Pages\World_Solar_Challenge.html
# Crawled_Pages\World_Sudoku_Championship.html
# Crawled_Pages\World_Team_Squash_Championships.html
# Crawled_Pages\World_Touring_Car_Championship.html
# Crawled_Pages\World_Weightlifting_Championships.html
# Crawled_Pages\World_Wheelchair_Rugby_Championships.html
# Crawled_Pages\World_Wrestling_Championships.html
# Crawled_Pages\World_Wushu_Championships.html
# Crawled_Pages\World_Yo-Yo_Contest.html
# Crawled_Pages\Wrestling_World_Cup.html
# Crawled_Pages\WSF_World_Team_Squash_Championships.html
# Crawled_Pages\WTBA_World_Tenpin_Bowling_Championships.html
# Crawled_Pages\Xare.html
# Crawled_Pages\Yak_polo.html
# Crawled_Pages\Yorkshire_County_Cricket_Club.html
# Crawled_Pages\Yubi_lakpi.html
# Crawled_Pages\Yukigassen.html
# Crawled_Pages\Yuvraj_Singh.html
# Crawled_Pages\Zebra.html
# Crawled_Pages\Zimbabwe.html
# Crawled_Pages\Zimbabwe_Cricket.html
# Crawled_Pages\Zimbabwe_national_cricket_team.html
# All done!

# %%
def posIndex(folder):
    #Create the index storage dictionary
    inv_index = {}
    doc_num = 0
    #Read all the files in the crawled pages folder
    for file in folder:
        doc_num += 1
        #Convert the file to a list of tokens, or words
        doc = getPosToken(file)
        #Get the postion of the word in the file
        word_pos = 0
        for word in doc:
            if word not in inv_index:
                #add the word to the dictionary as a key
                inv_index[word] = []
            #add (doc_num, word_pos) as the value to the dictionary
            key_list = []
            term = [doc_num,word_pos]
            key_list.append(term)
            inv_index[word] = key_list
            word_pos += 1
    #Write the inverted index to file
