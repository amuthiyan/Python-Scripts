# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dates = ['last_pymnt_d','last_credit_pull_d','issue_d','earliest_cr_line']
df1 = pd.read_csv('../Niteo/Lending/loan.csv/loan.csv',parse_dates=dates,infer_datetime_format=True)
df1.head()
# Out:
# C:\Users\amuthiyan\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade     ...      total_bal_il il_util  \
# 0     10.65       162.87     B        B2     ...               NaN     NaN
# 1     15.27        59.83     C        C4     ...               NaN     NaN
# ...

# %%
df=df1.copy()

# %%
count=df.addr_state.value_counts()
print count
# Out:
# CA    129517
# NY     74086
# TX     71138
# FL     60935
# IL     35476
# NJ     33256
# PA     31393
# OH     29631
# GA     29085
# VA     26255
# NC     24720
# MI     22985
# MD     21031
# MA     20593
# AZ     20412
# WA     19434
# CO     18807
# MN     15957
# MO     14207
# IN     13789
# CT     13531
# TN     12887
# NV     12443
# WI     11574
# AL     11200
# OR     10893
# SC     10639
# LA     10587
# KY      8550
# OK      8085
# KS      7926
# AR      6640
# UT      6264
# NM      4939
# HI      4570
# WV      4386
# NH      4294
# RI      3893
# MS      3819
# MT      2558
# DE      2511
# DC      2432
# AK      2205
# WY      2028
# SD      1815
# VT      1797
# NE      1176
# ME       525
# ND       479
# IA        14
# ID        12
# Name: addr_state, dtype: int64

# %%
df.issue_d
# Out:
# 0        2011-12-01
# 1        2011-12-01
# 2        2011-12-01
# 3        2011-12-01
# 4        2011-12-01
# 5        2011-12-01
# 6        2011-12-01
# 7        2011-12-01
# 8        2011-12-01
# 9        2011-12-01
# 10       2011-12-01
# 11       2011-12-01
# 12       2011-12-01
# 13       2011-12-01
# 14       2011-12-01
# 15       2011-12-01
# 16       2011-12-01
# 17       2011-12-01
# 18       2011-12-01
# 19       2011-12-01
# 20       2011-12-01
# 21       2011-12-01
# 22       2011-12-01
# 23       2011-12-01
# 24       2011-12-01
# 25       2011-12-01
# 26       2011-12-01
# 27       2011-12-01
# 28       2011-12-01
# 29       2011-12-01
#             ...
# 887349   2015-01-01
# 887350   2015-01-01
# 887351   2015-01-01
# 887352   2015-01-01
# 887353   2015-01-01
# 887354   2015-01-01
# 887355   2015-01-01
# 887356   2015-01-01
# 887357   2015-01-01
# 887358   2015-01-01
# 887359   2015-01-01
# 887360   2015-01-01
# 887361   2015-01-01
# 887362   2015-01-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887379 entries, 0 to 887378
# Data columns (total 74 columns):
# id                             887379 non-null int64
# member_id                      887379 non-null int64
# loan_amnt                      887379 non-null float64
# funded_amnt                    887379 non-null float64
# funded_amnt_inv                887379 non-null float64
# term                           887379 non-null object
# int_rate                       887379 non-null float64
# installment                    887379 non-null float64
# grade                          887379 non-null object
# sub_grade                      887379 non-null object
# emp_title                      835922 non-null object
# emp_length                     887379 non-null object
# home_ownership                 887379 non-null object
# annual_inc                     887375 non-null float64
# verification_status            887379 non-null object
# ...

# %%
l_range = '2009-01-01'
u_range = '2013-12-31'
df = df[(df.issue_d>l_range) & (df.issue_d<u_range)]
df.issue_d
# Out:
# 0        2011-12-01
# 1        2011-12-01
# 2        2011-12-01
# 3        2011-12-01
# 4        2011-12-01
# 5        2011-12-01
# 6        2011-12-01
# 7        2011-12-01
# 8        2011-12-01
# 9        2011-12-01
# 10       2011-12-01
# 11       2011-12-01
# 12       2011-12-01
# 13       2011-12-01
# 14       2011-12-01
# 15       2011-12-01
# 16       2011-12-01
# 17       2011-12-01
# 18       2011-12-01
# 19       2011-12-01
# 20       2011-12-01
# 21       2011-12-01
# 22       2011-12-01
# 23       2011-12-01
# 24       2011-12-01
# 25       2011-12-01
# 26       2011-12-01
# 27       2011-12-01
# 28       2011-12-01
# 29       2011-12-01
#             ...
# 230627   2012-01-01
# 230628   2012-01-01
# 230629   2012-01-01
# 230630   2012-01-01
# 230631   2012-01-01
# 230632   2012-01-01
# 230633   2012-01-01
# 230634   2012-01-01
# 230635   2012-01-01
# 230636   2012-01-01
# 230637   2012-01-01
# 230638   2012-01-01
# 230639   2012-01-01
# 230640   2012-01-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227392 entries, 0 to 230656
# Data columns (total 74 columns):
# id                             227392 non-null int64
# member_id                      227392 non-null int64
# loan_amnt                      227392 non-null float64
# funded_amnt                    227392 non-null float64
# funded_amnt_inv                227392 non-null float64
# term                           227392 non-null object
# int_rate                       227392 non-null float64
# installment                    227392 non-null float64
# grade                          227392 non-null object
# sub_grade                      227392 non-null object
# emp_title                      213203 non-null object
# emp_length                     227392 non-null object
# home_ownership                 227392 non-null object
# annual_inc                     227392 non-null float64
# verification_status            227392 non-null object
# ...

# %%
columns_to_delete = ['annual_inc_joint','dti_joint','verification_status_joint','open_acc_6m','open_il_6m','open_il_12m',\
                    'open_il_24m','mths_since_rcnt_il','total_bal_il','il_util','open_rv_12m','open_rv_24m',\
                    'max_bal_bc','all_util','inq_fi','total_cu_tl','inq_last_12m','next_pymnt_d',\
                    'mths_since_last_record','mths_since_last_major_derog','recoveries','tot_coll_amt','total_rev_hi_lim',\
                    'tot_cur_bal','collection_recovery_fee','collections_12_mths_ex_med','policy_code',\
                    'acc_now_delinq','total_rec_late_fee','out_prncp_inv','out_prncp','url']
df = df.drop(columns_to_delete,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227392 entries, 0 to 230656
# Data columns (total 42 columns):
# id                        227392 non-null int64
# member_id                 227392 non-null int64
# loan_amnt                 227392 non-null float64
# funded_amnt               227392 non-null float64
# funded_amnt_inv           227392 non-null float64
# term                      227392 non-null object
# int_rate                  227392 non-null float64
# installment               227392 non-null float64
# grade                     227392 non-null object
# sub_grade                 227392 non-null object
# emp_title                 213203 non-null object
# emp_length                227392 non-null object
# home_ownership            227392 non-null object
# annual_inc                227392 non-null float64
# verification_status       227392 non-null object
# issue_d                   227392 non-null datetime64[ns]
# loan_status               227392 non-null object
# ...

# %%
del df['desc']

# %%
df = df[df.loan_status == 'Fully Paid']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128294 entries, 0 to 230654
# Data columns (total 41 columns):
# id                        128294 non-null int64
# member_id                 128294 non-null int64
# loan_amnt                 128294 non-null float64
# funded_amnt               128294 non-null float64
# funded_amnt_inv           128294 non-null float64
# term                      128294 non-null object
# int_rate                  128294 non-null float64
# installment               128294 non-null float64
# grade                     128294 non-null object
# sub_grade                 128294 non-null object
# emp_title                 121342 non-null object
# emp_length                128294 non-null object
# home_ownership            128294 non-null object
# annual_inc                128294 non-null float64
# verification_status       128294 non-null object
# issue_d                   128294 non-null datetime64[ns]
# loan_status               128294 non-null object
# ...

# %%
df=df[(df.grade=='C')|(df.grade=='D')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46481 entries, 2 to 230654
# Data columns (total 41 columns):
# id                        46481 non-null int64
# member_id                 46481 non-null int64
# loan_amnt                 46481 non-null float64
# funded_amnt               46481 non-null float64
# funded_amnt_inv           46481 non-null float64
# term                      46481 non-null object
# int_rate                  46481 non-null float64
# installment               46481 non-null float64
# grade                     46481 non-null object
# sub_grade                 46481 non-null object
# emp_title                 44190 non-null object
# emp_length                46481 non-null object
# home_ownership            46481 non-null object
# annual_inc                46481 non-null float64
# verification_status       46481 non-null object
# issue_d                   46481 non-null datetime64[ns]
# loan_status               46481 non-null object
# ...

# %%
df['title']=df.title.fillna('Debt consolidation')

# %%
df['title']=df.title.apply(lambda x : x.lower())

# %%
df.title.value_counts()
# Out:
# debt consolidation                          8988
# consolidation                               1640
# credit card refinancing                     1344
# debt consolidation loan                     1066
# home improvement                             731
# credit card consolidation                    703
# personal loan                                685
# other                                        569
# consolidation loan                           544
# credit card payoff                           454
# credit card refinance                        437
# consolidate                                  428
# personal                                     425
# loan                                         323
# credit cards                                 284
# payoff                                       274
# debt                                         269
# business                                     266
# freedom                                      264
# ...

# %%
df['title']=df.title.replace(['credit card refinancing','consolidation','my loan'],['credit card refinance','consolidate','loan'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46481 entries, 2 to 230654
# Data columns (total 41 columns):
# id                        46481 non-null int64
# member_id                 46481 non-null int64
# loan_amnt                 46481 non-null float64
# funded_amnt               46481 non-null float64
# funded_amnt_inv           46481 non-null float64
# term                      46481 non-null object
# int_rate                  46481 non-null float64
# installment               46481 non-null float64
# grade                     46481 non-null object
# sub_grade                 46481 non-null object
# emp_title                 44190 non-null object
# emp_length                46481 non-null object
# home_ownership            46481 non-null object
# annual_inc                46481 non-null float64
# verification_status       46481 non-null object
# issue_d                   46481 non-null datetime64[ns]
# loan_status               46481 non-null object
# ...

# %%
df.title.value_counts()
# Out:
# debt consolidation                          8988
# consolidate                                 2068
# credit card refinance                       1781
# debt consolidation loan                     1066
# home improvement                             731
# credit card consolidation                    703
# personal loan                                685
# loan                                         570
# other                                        569
# consolidation loan                           544
# credit card payoff                           454
# personal                                     425
# credit cards                                 284
# payoff                                       274
# debt                                         269
# business                                     266
# freedom                                      264
# debt consolidation                           244
# credit card loan                             240
# ...

# %%
def repTitle(x):
    if 'debt' in x:
        x='debt'
    return x
df['title']=df.title.apply(repTitle)
df.title.value_counts()
# Out:
# debt                                        16110
# consolidate                                  2068
# credit card refinance                        1781
# home improvement                              731
# credit card consolidation                     703
# personal loan                                 685
# loan                                          570
# other                                         569
# consolidation loan                            544
# credit card payoff                            454
# personal                                      425
# credit cards                                  284
# payoff                                        274
# business                                      266
# freedom                                       264
# credit card loan                              240
# credit card                                   218
# major purchase                                202
# wedding                                       171
# ...

# %%
def defCred(x):
    if 'credit card' in x:
        if 'consolidat' in x:
            x='credit card consolidation'
        else:
            x='credit card debt'
    return x
df['title']=df.title.apply(defCred)
df.title.value_counts()
# Out:
# debt                                       16110
# credit card debt                            4890
# consolidate                                 2068
# credit card consolidation                   1033
# home improvement                             731
# personal loan                                685
# loan                                         570
# other                                        569
# consolidation loan                           544
# personal                                     425
# payoff                                       274
# business                                     266
# freedom                                      264
# major purchase                               202
# wedding                                      171
# wedding loan                                 156
# vacation                                     146
# medical expenses                             143
# home improvement loan                        134
# ...

# %%
def WedDef(x):
    if 'wedding' in x:
        x='wedding'
    return x
df['title']=df.title.apply(WedDef)
df.title.value_counts()
# Out:
# debt                                      16110
# credit card debt                           4890
# consolidate                                2068
# credit card consolidation                  1033
# home improvement                            731
# personal loan                               685
# wedding                                     631
# loan                                        570
# other                                       569
# consolidation loan                          544
# personal                                    425
# payoff                                      274
# business                                    266
# freedom                                     264
# major purchase                              202
# vacation                                    146
# medical expenses                            143
# home improvement loan                       134
# credit consolidation                        127
# pay off                                     127
# ...

# %%
def MedDef(x):
    if 'medical' in x:
        x='medical'
    return x
df['title']=df.title.apply(MedDef)
df.title.value_counts()
# Out:
# debt                                     16110
# credit card debt                          4890
# consolidate                               2068
# credit card consolidation                 1033
# home improvement                           731
# personal loan                              685
# wedding                                    631
# loan                                       570
# other                                      569
# consolidation loan                         544
# medical                                    453
# personal                                   425
# payoff                                     274
# business                                   266
# freedom                                    264
# major purchase                             202
# vacation                                   146
# home improvement loan                      134
# pay off                                    127
# credit consolidation                       127
# ...

# %%
def PerDef(x):
    if 'personal' in x:
        x='personal'
    return x
df['title']=df.title.apply(PerDef)
df.title.value_counts()
# Out:
# debt                                     16110
# credit card debt                          4890
# consolidate                               2068
# personal                                  1390
# credit card consolidation                 1033
# home improvement                           731
# wedding                                    631
# loan                                       570
# other                                      569
# consolidation loan                         544
# medical                                    453
# payoff                                     274
# business                                   266
# freedom                                    264
# major purchase                             202
# vacation                                   146
# home improvement loan                      134
# pay off                                    127
# credit consolidation                       127
# cc consolidation                           122
# ...

# %%
def HomeDef(x):
    if 'home' in x:
        x='home improvement'
    return x
df['title']=df.title.apply(HomeDef)
df.title.value_counts()
# Out:
# debt                                       16110
# credit card debt                            4890
# consolidate                                 2068
# home improvement                            1759
# personal                                    1390
# credit card consolidation                   1033
# wedding                                      631
# loan                                         570
# other                                        569
# consolidation loan                           544
# medical                                      453
# payoff                                       274
# business                                     266
# freedom                                      264
# major purchase                               202
# vacation                                     146
# credit consolidation                         127
# pay off                                      127
# cc consolidation                             122
# ...

# %%
df['title']=df.title.replace(['consolidation loan','loan 1','lending club loan'],['loan consolidation','loan','lending club'])

# %%
df.title.value_counts()
# Out:
# debt                                       16110
# credit card debt                            4890
# consolidate                                 2068
# home improvement                            1759
# personal                                    1390
# credit card consolidation                   1033
# loan                                         645
# wedding                                      631
# loan consolidation                           624
# other                                        569
# medical                                      453
# payoff                                       274
# business                                     266
# freedom                                      264
# major purchase                               202
# vacation                                     146
# lending club                                 136
# credit consolidation                         127
# pay off                                      127
# ...

# %%
df['title'] = df.title.replace(['cc consolidation'],['credit card consolidation'])
df.title.value_counts()
# Out:
# debt                                       16110
# credit card debt                            4890
# consolidate                                 2068
# home improvement                            1759
# personal                                    1390
# credit card consolidation                   1155
# loan                                         645
# wedding                                      631
# loan consolidation                           624
# other                                        569
# medical                                      453
# payoff                                       274
# business                                     266
# freedom                                      264
# major purchase                               202
# vacation                                     146
# lending club                                 136
# pay off                                      127
# credit consolidation                         127
# ...

# %%
def Off(x):
    if ('off' in x) | ('cc ' in x):
        x='credit card debt'
    return x
df['title']=df.title.apply(Off)
df.title.value_counts()
# Out:
# debt                                   16110
# credit card debt                        6788
# consolidate                             2068
# home improvement                        1759
# personal                                1390
# credit card consolidation               1155
# loan                                     645
# wedding                                  631
# loan consolidation                       624
# other                                    569
# medical                                  453
# business                                 266
# freedom                                  264
# major purchase                           202
# vacation                                 146
# lending club                             136
# credit consolidation                     127
# bill consolidation                       108
# refinance                                107
# small business loan                      100
# bills                                     90
# ...

# %%
def Bill(x):
    if 'bill' in x:
        x='bills'
    return x
df['title']=df.title.apply(Bill)
df.title.value_counts()
# Out:
# debt                                    16110
# credit card debt                         6788
# consolidate                              2068
# home improvement                         1759
# personal                                 1390
# credit card consolidation                1155
# loan                                      645
# wedding                                   631
# loan consolidation                        624
# bills                                     589
# other                                     569
# medical                                   453
# business                                  266
# freedom                                   264
# major purchase                            202
# vacation                                  146
# lending club                              136
# credit consolidation                      127
# refinance                                 107
# small business loan                       100
# ...

# %%
df['title']=df.title.replace(['loan1'],['loan'])
df.title.value_counts()
# Out:
# debt                                    16110
# credit card debt                         6788
# consolidate                              2068
# home improvement                         1759
# personal                                 1390
# credit card consolidation                1155
# loan                                      698
# wedding                                   631
# loan consolidation                        624
# bills                                     589
# other                                     569
# medical                                   453
# business                                  266
# freedom                                   264
# major purchase                            202
# vacation                                  146
# lending club                              136
# credit consolidation                      127
# refinance                                 107
# small business loan                       100
# ...

# %%
def Bus(x):
    if 'business' in x:
        x='business'
    return x
df['title']=df.title.apply(Bus)
df.title.value_counts()
# Out:
# debt                                   16110
# credit card debt                        6788
# consolidate                             2068
# home improvement                        1759
# personal                                1390
# credit card consolidation               1155
# business                                 706
# loan                                     698
# wedding                                  631
# loan consolidation                       624
# bills                                    589
# other                                    569
# medical                                  453
# freedom                                  264
# major purchase                           202
# vacation                                 146
# lending club                             136
# credit consolidation                     127
# refinance                                107
# car loan                                  89
# credit                                    63
# ...

# %%
def Car(x):
    if 'car ' in x:
        x='car loan'
    return x
df['title']=df.title.apply(Car)
df.title.value_counts()
# Out:
# debt                                     16110
# credit card debt                          6788
# consolidate                               2068
# home improvement                          1759
# personal                                  1390
# credit card consolidation                 1155
# business                                   706
# loan                                       698
# wedding                                    631
# loan consolidation                         624
# bills                                      589
# other                                      569
# medical                                    453
# car loan                                   281
# freedom                                    264
# major purchase                             202
# vacation                                   146
# lending club                               136
# credit consolidation                       127
# refinance                                  107
# ...

# %%
df['title']=df.title.replace(['consolidation','moving and relocation'],['loan consolidation','moving'])
df.title.value_counts()
# Out:
# debt                                     16110
# credit card debt                          6788
# consolidate                               2068
# home improvement                          1759
# personal                                  1390
# credit card consolidation                 1155
# business                                   706
# loan                                       698
# wedding                                    631
# loan consolidation                         624
# bills                                      589
# other                                      569
# medical                                    453
# car loan                                   281
# freedom                                    264
# major purchase                             202
# vacation                                   146
# lending club                               136
# credit consolidation                       127
# refinance                                  107
# ...

# %%
def Mov(x):
    if 'moving ' in x:
        x='moving'
    return x
df['title']=df.title.apply(Car)
df.title.value_counts()
# Out:
# debt                                     16110
# credit card debt                          6788
# consolidate                               2068
# home improvement                          1759
# personal                                  1390
# credit card consolidation                 1155
# business                                   706
# loan                                       698
# wedding                                    631
# loan consolidation                         624
# bills                                      589
# other                                      569
# medical                                    453
# car loan                                   281
# freedom                                    264
# major purchase                             202
# vacation                                   146
# lending club                               136
# credit consolidation                       127
# refinance                                  107
# ...

# %%
def Pool(x):
    if 'pool ' in x:
        x='pool'
    return x
df['title']=df.title.apply(Pool)
df.title.value_counts()
# Out:
# debt                                        16110
# credit card debt                             6788
# consolidate                                  2068
# home improvement                             1759
# personal                                     1390
# credit card consolidation                    1155
# business                                      706
# loan                                          698
# wedding                                       631
# loan consolidation                            624
# bills                                         589
# other                                         569
# medical                                       453
# car loan                                      281
# freedom                                       264
# major purchase                                202
# vacation                                      146
# lending club                                  136
# pool                                          135
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46481 entries, 2 to 230654
# Data columns (total 41 columns):
# id                        46481 non-null int64
# member_id                 46481 non-null int64
# loan_amnt                 46481 non-null float64
# funded_amnt               46481 non-null float64
# funded_amnt_inv           46481 non-null float64
# term                      46481 non-null object
# int_rate                  46481 non-null float64
# installment               46481 non-null float64
# grade                     46481 non-null object
# sub_grade                 46481 non-null object
# emp_title                 44190 non-null object
# emp_length                46481 non-null object
# home_ownership            46481 non-null object
# annual_inc                46481 non-null float64
# verification_status       46481 non-null object
# issue_d                   46481 non-null datetime64[ns]
# loan_status               46481 non-null object
# ...

# %%
df.boxplot('int_rate','addr_state',figsize=(15,10))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46481 entries, 2 to 230654
# Data columns (total 41 columns):
# id                        46481 non-null int64
# member_id                 46481 non-null int64
# loan_amnt                 46481 non-null float64
# funded_amnt               46481 non-null float64
# funded_amnt_inv           46481 non-null float64
# term                      46481 non-null object
# int_rate                  46481 non-null float64
# installment               46481 non-null float64
# grade                     46481 non-null object
# sub_grade                 46481 non-null object
# emp_title                 44190 non-null object
# emp_length                46481 non-null object
# home_ownership            46481 non-null object
# annual_inc                46481 non-null float64
# verification_status       46481 non-null object
# issue_d                   46481 non-null datetime64[ns]
# loan_status               46481 non-null object
# ...

# %%
df.purpose.value_counts()
# Out:
# debt_consolidation    27414
# credit_card            8810
# other                  3008
# home_improvement       2261
# major_purchase         1089
# small_business          967
# wedding                 630
# car                     605
# medical                 548
# moving                  403
# vacation                331
# house                   284
# educational              75
# renewable_energy         56
# Name: purpose, dtype: int64

# %%
df=df.drop(['title'],axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46481 entries, 2 to 230654
# Data columns (total 40 columns):
# id                        46481 non-null int64
# member_id                 46481 non-null int64
# loan_amnt                 46481 non-null float64
# funded_amnt               46481 non-null float64
# funded_amnt_inv           46481 non-null float64
# term                      46481 non-null object
# int_rate                  46481 non-null float64
# installment               46481 non-null float64
# grade                     46481 non-null object
# sub_grade                 46481 non-null object
# emp_title                 44190 non-null object
# emp_length                46481 non-null object
# home_ownership            46481 non-null object
# annual_inc                46481 non-null float64
# verification_status       46481 non-null object
# issue_d                   46481 non-null datetime64[ns]
# loan_status               46481 non-null object
# ...

# %%
df.emp_title.value_counts()
# Out:
# US Army                                 143
# Teacher                                 120
# Bank of America                          99
# Manager                                  98
# USAF                                     73
# AT&T                                     71
# Kaiser Permanente                        66
# RN                                       61
# Walmart                                  60
# USPS                                     58
# Wells Fargo                              50
# State of California                      50
# US ARMY                                  47
# United States Air Force                  47
# Department of Defense                    46
# Registered Nurse                         46
# JPMorgan Chase                           44
# Supervisor                               44
# JP Morgan Chase                          44
# Verizon Wireless                         43
# U.S. Army                                41
# ...

# %%
def repDef(x):
    x=x.lower()
