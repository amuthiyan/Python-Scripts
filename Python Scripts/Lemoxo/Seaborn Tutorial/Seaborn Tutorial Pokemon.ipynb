# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import cm
import seaborn as sns

# %%
#Import the Pokemon csv
df = pd.read_csv('Pokemon.csv',encoding='ISO-8859-1')
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
df = df.rename(columns={'Type 1':'Type_1','Type 2':'Type_2','Sp. Atk':'Sp_Attack','Sp. Def':'Sp_Defense'})
df.head()
# Out:
#    #        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Attack  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49         65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63         80
# 2  3    Venusaur  Grass  Poison    525  80      82       83        100
# 3  4  Charmander   Fire     NaN    309  39      52       43         60
# 4  5  Charmeleon   Fire     NaN    405  58      64       58         80
#
#    Sp_Defense  Speed  Stage  Legendary
# 0          65     45      1      False
# 1          80     60      2      False
# 2         100     80      3      False
# 3          50     65      1      False
# 4          65     80      2      False

# %%
df.Type_2.fillna('None',inplace=True)
df.head()
# Out:
#    #        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Attack  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49         65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63         80
# 2  3    Venusaur  Grass  Poison    525  80      82       83        100
# 3  4  Charmander   Fire    None    309  39      52       43         60
# 4  5  Charmeleon   Fire    None    405  58      64       58         80
#
#    Sp_Defense  Speed  Stage  Legendary
# 0          65     45      1      False
# 1          80     60      2      False
# 2         100     80      3      False
# 3          50     65      1      False
# 4          65     80      2      False

# %%
sns.boxplot(x='Stage',y='Total',data=df)

# %%
sns.violinplot(x='Stage',y='Total',data=df)

# %%
sns.swarmplot(x='Stage',y='Total',data=df)

# %%
for i in range(5,10):
    plt.title(columns[i]+' by Stage')
    sns.swarmplot(x='Stage',y=columns[i],data=df)
    plt.show()

# %%
def TypeCount(x):
    if x=='None':
        return 1
    else:
        return 0
df['SingleType'] = df.Type_2.apply(TypeCount)
df.head()
# Out:
#    #        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Attack  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49         65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63         80
# 2  3    Venusaur  Grass  Poison    525  80      82       83        100
# 3  4  Charmander   Fire    None    309  39      52       43         60
# 4  5  Charmeleon   Fire    None    405  58      64       58         80
#
#    Sp_Defense  Speed  Stage  Legendary  SingleType
# 0          65     45      1      False           0
# 1          80     60      2      False           0
# 2         100     80      3      False           0
# 3          50     65      1      False           1
# 4          65     80      2      False           1

# %%
sns.distplot(df.Attack)

# %%
sns.distplot(df.HP)

# %%
sns.pairplot(data=df,hue='Stage',vars=columns[5:11])

# %%
sns.lmplot(x='HP',y='Sp_Defense',hue='Stage',data=df,fit_reg=False)

# %%
corr=df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True,square=True)
