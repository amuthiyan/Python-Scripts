# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import cm
import seaborn as sns
#Importing homemade functions
from Healthcare_EDA_functions import *

# %%
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.externals import joblib

# %%
#Modify the supervisor variable and add the Supervisor Rating
class Rate_Supervisor(TransformerMixin):
    
    def __init__(self,d_supervisors):
        self.goodL1 = d_supervisors['goodL1']
        self.badL1 = d_supervisors['badL1']
        self.goodL2 = d_supervisors['goodL2']
        self.badL2 = d_supervisors['badL2']
        pass
    
    def transform(self,X,y=None):
        #Fix L1 Supervisor Ratings
        badL1_lst=badL1_grp.index
        goodL1_lst = goodL1_grp.index
        X['L1_Supervisor_Rating'] = X.L1Supervisor.apply(lambda x: sortL1(x,badL1_lst,goodL1_lst))
        #Fix L2 Supervisor Ratings
        goodL2_grp = fixL2_grp[fixL2_grp.percent_resigned<26]
        badL2_lst=badL2_grp.index
        goodL2_lst = goodL2_grp.index
        X['L2_Supervisor_Rating'] = X.L2Supervisor.apply(lambda x: sortL2(x,badL2_lst,goodL2_lst))
        return X
    
    def fit(self,X,y):
        return self

# %%
#Split the Designation variable into three component pieces
class Split_Designation(TransformerMixin):
    
    def __init__(self):
        pass
    
    def transform(self,X,y=None):
        X = pd.DataFrame(X)
        X['primary_designation'] = X.Designation.apply(split_desig_prim)
        X['secondary_designation'] = X.Designation.apply(split_desig_sec)
        X['descriptor_designation'] = X.Designation.apply(split_desig_des)
        X['secondary_designation'] = X.secondary_designation.fillna('not_assigned')
        return X
    
    def fit(self,X,y):
        return self

# %%
#Add the Client Rating variable
class Rate_Clients(TransformerMixin):
    
    def __init__(self):
        pass
    
    def transform(self,X,y=None):
        clients_bad = ['ALN', 'Athena', 'Brightree', 'Cymetrix', 'HAP', 'PPM', 'Source Medical', 'TPX']
        clients_good = ['Altruis', 'Continuum', 'MRG', 'Shared Services', 'T-Systems', 'Zotec', 'abeo']
        bad_clients = clients_bad
        good_clients = clients_good
        X['Client_Rating'] = X.Client.apply(lambda x: sortClients(x,bad_clients,good_clients))
        return X
    
    def fit(self,X,y):
        return self

# %%
#Split the Functionality Variable
class Split_Functionality(TransformerMixin):
    
    def __init__(self):
        pass
    
    def transform(self,X,y=None):
        X['secondary_functionality'] = X.Functionality.apply(split_functionality)
        X['primary_functionality']=X.Functionality.apply(split_functionality2)
        X['secondary_functionality']=X.secondary_functionality.fillna('none')
        return X
    
    def fit(self,X,y):
        return self

# %%
#Create the variables relating to age_at_join
class Calc_Age(TransformerMixin):
    
    def __init__(self):
        pass
    
    def transform(self,X,y=None):
        X['age_at_join'] = (X['DOJ'] - X['DOB']) / np.timedelta64(1, 'D')
        return X
    
    def fit(self,X,y):
        return self

# %%
#Modify the Pincode Variable and add Districts and Moved variable
class Add_District(TransformerMixin):
    
    def __init__(self):
        pass
    
    def import_districts(district_file):
        pin_tab = pd.read_csv(district_file,encoding='ISO-8859-1')
        pin_tab = pin_tab.loc[0::,['pincode','Districtname','statename']]
        pin_tab=pin_tab.drop_duplicates(subset='pincode',keep='first')
        return pin_tab
    
    
    def add_moved(X):
        X['Per_Pincode'] = np.where(X['Per_Pincode'].isnull(),X['Pre_Pincode'],X['Per_Pincode'])
        X['Moved'] = np.where(X['Pre_Pincode']==X['Per_Pincode'],'no','yes')
        return X
    
    def transform(self,X,y=None):
        pin_tab = Add_District.import_districts('all_india_pin_code.csv')
        X = Add_District.add_districts(X,pin_tab)
        X = Add_District.add_moved(X)
        return X

    def add_districts(X,pin_tab):
        X = pd.merge(left=X,right=pin_tab[['Districtname']],left_on=['Pre_Pincode'],right_on=pin_tab['pincode'],how='left')
        X['Districts'] = X.Districtname.apply(district_group)
        X.Districts.fillna('Unknown',inplace=True)
        return X        
    
    def fit(self,X,y):
        return self

# %%
#Cleanup the Highest Degree field
class Clean_HighestDegree(TransformerMixin):
    
    def __init__(self):
        pass
    
    def transform(self,X,y=None):
        X.HighestDegree.fillna('None',inplace=True)
        X['HighestDegree'] = X.HighestDegree.astype(str)
        X['HighestDegree'] = X.HighestDegree.apply(clean_column)
        X['HighestDegree'] = X.HighestDegree.apply(RepBSC)
        X['HighestDegree'] = X.HighestDegree.apply(RepBCOM)
        X['HighestDegree'] = X.HighestDegree.apply(RepBE)
        X['HighestDegree'] = X.HighestDegree.apply(RepBCA)
        X['HighestDegree'] = X.HighestDegree.apply(RepBPHARM)
        X['HighestDegree'] = X.HighestDegree.apply(RepBTECH)
        X['HighestDegree'] = X.HighestDegree.apply(RepBA)
        X['HighestDegree'] = X.HighestDegree.apply(RepMSC)
        X['HighestDegree'] = X.HighestDegree.apply(RepMBA)
        X['HighestDegree'] = X.HighestDegree.apply(RepBCS)
        X['HighestDegree'] = X.HighestDegree.apply(RepBBA)
        X['HighestDegree'] = X.HighestDegree.apply(RepBBM)
        X['HighestDegree'] = X.HighestDegree.apply(RepMCA)
        X['HighestDegree'] = X.HighestDegree.apply(RepBE2)
        X['HighestDegree'] = X.HighestDegree.apply(RepDip)
        X['HighestDegree'] = X.HighestDegree.apply(MPharm)
        X['HighestDegree'] = X.HighestDegree.apply(clean_desig)
        X['degree_title'] = X.HighestDegree.apply(split_degree)
        return X
    
    def fit(self,X,y):
        return self

# %%
#Create the total leaves variable
class Add_Leaves(TransformerMixin):
    
    def __init__(self):
        self.sick = X.NoOfSickLeaveAvailed
        self.casual = X.NoOfCLAvailed
        pass
    
    def transform(self,X,y=None):
        X['total_leaves'] = self.casual + self.sick
        return X
    
    def fit(self,X,y):
        return self

# %%
#Add misc. variables
class Add_Vars(TransformerMixin):
    
    def __init__(self):
        pass
    
    def transform(self,X,y=None):
        X['Operation_Assistant'] = np.where(((X['primary_functionality']=='operations') & 
                                       (X['primary_designation']=='assistant')),1,0)
        X['Shared_Software'] = np.where(((X['primary_functionality']=='shared services') & 
                                       (X['primary_designation']=='software')),1,0)
        X=X.rename(columns={'Productivity%':'Productivity','Quality%':'Quality'})
        #Variable for when Productivity is null and Quality isn't
        X['NullProd'] = np.where((X.Productivity.isnull() & X.Quality.notnull()),1,0)
        #Variable for when Quality is null and Productivity isn't
        X['NullQual'] = np.where((X.Quality.isnull() & X.Productivity.notnull()),1,0)
        #Variable for when both Productivity and Quality are null
        X['Both_Null_Prod_Qual'] = np.where((X.Quality.isnull() & X.Productivity.isnull()),1,0)
        return X
    
    def fit(self,X,y):
        return self

# %%
#Keep only useful features
class Keep_Features(TransformerMixin):
    
    def __init__(self):
        self.feats =['Gender','primary_designation','secondary_designation',\
           'Client','secondary_functionality','MaritalStatus','NullProd','NullQual','Both_Null_Prod_Qual',\
           'HighestDegree','primary_functionality','Districts','PrevCompanyExp','Moved',\
           'total_leaves','age_at_join','degree_title','Dependents','Productivity','LateEntry',\
           'Operation_Assistant','Shared_Software','Shift']
        pass
    
    def transform(self,X,y=None):
        
        X = X[self.feats]
        return X
    
    def fit(self,X,y):
        return self

# %%
#Create dummy variables
class Dummy(TransformerMixin):
    
    def __init__(self,d_accepted):
        self.d_accepted = d_accepted
        pass
    
    def transform(self,X,y=None):
        for var in X.columns:
            if X[var].dtypes == object:
                X[var] = pd.Categorical(X[var],self.d_accepted[var])
        X = pd.get_dummies(X)
        return X
        
    def fit(self,X,y):
        return self

# %%
#Impute values for Productivity
class Impute(TransformerMixin):
    
    def __init__(self,mean):
        self.mean = mean
        pass
    
    def transform(self,X,y=None):
        X['Productivity']=X.Productivity.fillna(self.mean)
        return X
    
    def fit(self,X,y):
        return self

# %%
X
# Out:
#        Empcode                              Name Gender     L1Supervisor  \
# 0       C07383              Dineshkumar Umapathi      M   seju.sebastian
# 1      F034899              Rajeshwari Amarsingh      F  sathishkumar.ch
# 2      E093441                         Abinash S      M  rathish.seethar
# 3      D051008                      Logesh Kumar      M  sathishkumar.ch
# 4      F116696                            Raja K      M          rajan.s
# 5      G038672                       Posen Nokpa      F   seju.sebastian
# 6      F126884                       Vinothini J      F  nishamary.kuria
# 7      F126978                    Bhaskar Sawant      M   sarita.raitani
# 8      F127004                  Bickas Bahadur T      M  aliakbar.sibbak
# 9      D081399                      Mythili Devi      F  sivashankar.chi
# 10     E073222              Kannan Panneerselvam      M     manigandan.j
# 11     E093453            Parthiban Chandrasekar      M     lakshmanan.c
# 12     F126918                      Maruf Sayyad      M  sakthivel.selva
# 13     F126753                    Harish Kumar D      M  yograj.manohara
# 14     F126979                  Harshal Shrawagi      M   sarita.raitani
# 15     G027530                   Kalyana Kumar A      M  thangam.neerath
# 16     F127009                     Sureshkumar P      M    sathiadasan.v
# 17     F127012                   John Melkyias Z      M  herojirao.premn
# 18     E103756                          Balaji R      M  Hanumanthraj.Go
# 19     E113937                         Kavitha E      F  swadhini.paramb
# 20     G069683                      Bakyavathi S      F  senthilvel.dura
# 21     F024683                        Uday Gupta      M  mohan.krishname
# 22     E124186                            Velu C      M  jayanthy.nagara
# 23     G037810                     Mohan Kumar P      M    devi.ramasamy
# 24     G038257                   Purushothaman R      M     yoganandan.r
# 25     G038423                 Shabana Parveen P      F   muthumanikan.a
# 26     G059359                   Rajendrakumar R      M       yuvaraj.s2
# 27     G038431                    Syed Ibrahim S      M  vimaladhitha.na
# 28     G049177                        Sharmila V      F  prasanna.athina
# 29     G038723                        Harish M K      M        rajesh.s9
# ...        ...                               ...    ...              ...
# 9345  H0212406                       Saravanan S      M     sivakumar.r5
# 9346  H0212042                        Karthi M S      M    gayathri.ravi
# 9347   F075749            Manova Jayakirubakaran      M      Ganesh.Ravi
# 9348   F085949                         Saranya V      F   kolanjinatha.r
# 9349  H0212060                         Porkodi S      F  benoy.somanatha
# 9350  H0212287                    Jeanchui Kamei      M  mohan.krishname
# 9351  H0312586                     Shruthi Sneha      F   joseph.daniel1
# 9352  H0312558                     Padma Priya K      F  edwinanthony.la
# 9353  H0312778                        Nandhini S      F  sathish.kadirve
# 9354  H0111998                         Lavanya S      F  basker.selvaraj
# 9355   F096206                      Damaji Halle      M  rajesh.singhani
# 9356   F096204                       Ajay Vinchu      M  rajesh.singhani
# 9357   F096210                        Ajay Sable      M    samadhan.wagh
# 9358  G1110854                         Nithiya G      F  sathish.kadirve
# 9359  G1211140                       Manimaran K      M   virushabanat.a
# 9360  G1110834                        Jayanthi K      F        sathya.r1
# 9361  G1110930                     Anthony Raj A      M   karthikeyan.ms
# 9362   F024575                    Durgesh Mishra      M  praveen.agarkar
# 9363   F065391           Prabakaran Jayasundaram      M  kalpana.sudalai
# 9364   F065463  Sivabalakrishnan Kanagasabapathy      M  kannan.poornali
# 9365   F085993                  Nikita R Lovedel      F  shrikaant.gaval
# 9366  H0111795                    Nagabushanam K      M     selvinbabu.m
# 9367  H0111583                      Prasanth Y S      M  kalpana.sudalai
# 9368  H0111881                    Mathan Kumar P      M     vivek.murali
# 9369  H0312530                    Kamatchi Rajan      F         renuka.k
# 9370  H0112008                        Elamathi G      F  gavaskaran.peri
# 9371  H0111655                         Vignesh V      M  sarathkumar.sas
# 9372  H0111557                         Gautham M      M  sivashankar.chi
# 9373  H0111961                       Pooja Salve      F    mayur.murkute
# 9374  H0112010                       Ravindran V      M  gavaskaran.peri
#
#           L2Supervisor               Designation           Client  \
# 0      harish.chandras     Assistant Team Leader   Source Medical
# 1      kannan.poornali                 Executive           Athena
# 2            magesh.m1          Senior Executive  Shared Services
# 3      kannan.poornali          Senior Executive           Athena
# 4       sathishkumar.j                 Executive           Athena
# 5      harish.chandras        Senior Team Leader   Source Medical
# 6          mirza.karim       Assistant Executive           Athena
# 7       suleman.shaikh       Assistant Executive           Athena
# 8      rajkumar.balasu                 Executive           Athena
# 9       nirmalvickne.s     Subject Matter Expert              ALN
# 10       santhosh.jose          Senior Executive              ALN
# 11     mohan.nagarajan          Senior Executive            Zotec
# 12         madhavan.gg  Desktop Support Engineer  Shared Services
# 9372                         Operations - Revenue Cycle 2017-01-02 1991-06-29
# 9373            Operations - Clinical Document Services 2017-01-27 1994-08-03
# 9374            Operations - Clinical Document Services 2017-01-30 1988-10-11
#
#          ...     Shift  L1_Supervisor_Rating  L2_Supervisor_Rating  \
# 0        ...       Day                   Bad               Neutral
# 1        ...       Day                   Bad                   Bad
# 2        ...       Day                  Good               Neutral
# 3        ...       Day                   Bad                   Bad
# 4        ...       Day                   Bad                   Bad
# 5        ...       Day                   Bad               Neutral
# 6        ...       Day               Neutral                   Bad
# 7        ...       Day                   Bad                  Good
# 8        ...       Day                   Bad               Neutral
# 9        ...       Day                   Bad                   Bad
# 10       ...       Day                  Good                  Good
# 11       ...       Day                   Bad                  Good
# 12       ...       Day               Neutral               Neutral
# 13       ...       Day                  Good                   Bad
# 14       ...       Day                   Bad                  Good
# 15       ...       Day               Neutral                   Bad
# 16       ...       Day               Neutral                   Bad
# 17       ...       Day                   Bad                   Bad
# 18       ...       Day               Neutral                  Good
# 19       ...       Day               Neutral                   Bad
# 20       ...       Day                   Bad                   Bad
# 21       ...       Day                  Good                   Bad
# 22       ...       Day                   Bad                   Bad
# 23       ...       Day                  Good                  Good
# 24       ...       Day                   Bad                   Bad
# 25       ...       Day                  Good                  Good
# 26       ...       Day                  Good                  Good
# 27       ...       Day                   Bad                   Bad
# 28       ...       Day                  Good                  Good
# 29       ...       Day                  Good                  Good
# ...      ...       ...                   ...                   ...
# 9345     ...       Day                  Good                  Good
# 9346     ...       Day                  Good                   Bad
# 9347     ...       Day                  Good                   Bad
# 9348     ...       Day                  Good                   Bad
# 9349     ...       Day                  Good                  Good
# 9350     ...       Day                  Good                   Bad
# 9351     ...       Day                  Good                   Bad
# 9352     ...       Day               Neutral                  Good
# 9353     ...       Day                  Good                  Good
# 9354     ...       Day                  Good                   Bad
# 9355     ...       Day                   Bad               Neutral
# 9356     ...       Day                   Bad               Neutral
# 9357     ...       Day                   Bad                   Bad
# 9358     ...       Day                  Good                  Good
# 9359     ...       Day                  Good                  Good
# 9360     ...       Day                   Bad                   Bad
# 9361     ...       Day                   Bad                   Bad
# 9362     ...       Day               Neutral                   Bad
# 9363     ...       Day                   Bad                   Bad
# 9364     ...       Day                  Good                   Bad
# 9365     ...       Day               Neutral                   Bad
# 9366     ...       Day                  Good               Neutral
# 9367     ...       Day                   Bad                   Bad
# 9368     ...       Day                   Bad               Neutral
# 9369     ...       Day                  Good                  Good
# 9370     ...       Day               Neutral                   Bad
# 9371     ...       Day                   Bad                   Bad
# 9372     ...       Day                   Bad                   Bad
# 9373     ...       Day                  Good                  Good
# 9374     ...       Day               Neutral                   Bad
#
#       primary_designation  secondary_designation descriptor_designation  \
# 0               assistant           team leader                    None
# 1               executive                                          None
# 2                  senior             executive                    None
# 3                  senior             executive                    None
# 4               executive                                          None
# 5                  senior           team leader                    None
# 6               assistant             executive                    None
# 7               assistant             executive                    None
# 8               executive                                          None
# 9                 subject         matter expert                    None
# 10                 senior             executive                    None
# 11                 senior             executive                    None
# 12                desktop      support engineer                    None
# 13              assistant             executive                    None
# 14              executive                                          None
# 15              assistant           team leader                    None
# 16                 senior             executive                    None
# 17              executive                                          None
# 18                 senior             executive                    None
# 19                   team                leader                    None
# 20              assistant             executive                    None
# 21                 senior             executive                    None
# 22                 senior             executive                    None
# 23              executive                                          None
# 24              executive                                          None
# 25              executive                                          None
# 26                 senior             executive                    None
# 27              executive                                          None
# 28              executive                                          None
# 29              executive                                          None
# ...                   ...                    ...                    ...
# 9345            executive                                          None
# 9346            assistant             executive                    None
# 9347            executive                                          None
# 9348            executive                                          None
# 9349               senior             executive                    None
# 9350            assistant             executive                    None
# 9351            assistant             executive                    None
# 9352               senior             executive                    None
# 9353            assistant             executive                    None
# 9354            executive                                          None
# 9355            executive                                          None
# 9356            executive                                          None
# 9357            assistant             executive                    None
# 9358            assistant             executive                    None
# 9359            assistant             executive                    None
# 9360            assistant             executive                    None
# 9361            executive                                          None
# 9362            assistant           team leader                    None
# 9363               senior             executive                    None
# 9364               senior             executive                    None
# 9365            assistant           team leader                    None
# 9366               senior             executive                    None
# 9367            assistant             executive                    None
# 9368            executive                                          None
# 9369               senior             executive                    None
# 9370            assistant             executive                    None
# 9371            assistant             executive                    None
# 9372               senior             executive                    None
# 9373            assistant             executive                    None
# 9374            assistant             executive                    None
#
#       Client_Rating         secondary_functionality primary_functionality  \
# 0               Bad                   revenue cycle            operations
# 1               Bad      clinical document services            operations
# 2              Good                  human resource       shared services
# 3               Bad                        clinical            operations
# 4               Bad                      data entry            operations
# 5               Bad                   revenue cycle            operations
# 6               Bad                      data entry            operations
# 7               Bad                        clinical            operations
# 8               Bad     payments posting data entry            operations
# 9               Bad                   revenue cycle            operations
# 10              Bad                         billing            operations
# 11             Good                         billing            operations
# 12             Good        infrastructure solutions       shared services
# 13              Bad                         denials            operations
# 14              Bad      clinical document services            operations
# 15              Bad                 posting quality            operations
# 16              Bad                           voice            operations
# 17              Bad     payments posting data entry            operations
# 18              Bad                micro clustering            operations
# 19              Bad                        clinical            operations
# 20              Bad         aetna claims processing            operations
# 21              Bad                  prescribed low            operations
# 22              Bad                           voice            operations
# 23              Bad     payments posting data entry            operations
# 24              Bad               remittance record            operations
# 25              Bad               specified denials            operations
# 26              Bad      clinical document services            operations
# 27              Bad                        clinical            operations
# 28          Neutral                         billing            operations
# 29              Bad       remittance record posting            operations
# ...             ...                             ...                   ...
# 9345           Good                         billing            operations
# 9346            Bad             unspecified denials            operations
# 9347            Bad                         billing            operations
# 9348            Bad             payments data entry            operations
# 9349           Good                   revenue cycle            operations
# 9350            Bad                  prescribed low            operations
# 9351        Neutral                   revenue cycle            operations
# 9352            Bad                  prescribed low            operations
# 9353            Bad  expanded client work reduction            operations
# 9354            Bad                         billing            operations
# 9355            Bad      clinical document services            operations
# 9356            Bad                        clinical            operations
# 9357            Bad                        clinical            operations
# 9358            Bad                           voice            operations
# 9359            Bad      clinical document services            operations
# 9360            Bad      clinical document services            operations
# 9361            Bad                 prescribed high            operations
# 9362            Bad      clinical document services            operations
# 9363            Bad      clinical document services            operations
# 9364            Bad      clinical document services            operations
# 9365            Bad                        clinical            operations
# 9366            Bad                          coding            operations
# 9367            Bad      clinical document services            operations
# 9368           Good                   revenue cycle            operations
# 9369           Good                          coding            operations
# 9370            Bad      clinical document services            operations
# 9371            Bad      clinical document services            operations
# 9372           Good                   revenue cycle            operations
# 9373            Bad      clinical document services            operations
# 9374            Bad      clinical document services            operations
#
#      age_at_join
# 0         9519.0
# 1         8282.0
# 2         8080.0
# 3         7961.0
# 4        10058.0
# 5        10694.0
# 6         9713.0
# 7         9297.0
# 8         7462.0
# 9         8565.0
# 10        8719.0
# 11        7354.0
# 12        8496.0
# 13        8372.0
# 14        8686.0
# 15       13273.0
# 16        9625.0
# 17        7875.0
# 18        9125.0
# 19       10160.0
# 20        8447.0
# 21       10322.0
# 22        7948.0
# 23        7776.0
# 24       42439.0
# 25        8211.0
# 26        9944.0
# 27       42439.0
# 28        8465.0
# 29        7721.0
# ...          ...
# 9345      8645.0
# 9346      8873.0
# 9347      7406.0
# 9348      7658.0
# 9349     10142.0
# 9350      8369.0
# 9351      8484.0
# 9352      8713.0
# 9353      9786.0
# 9354      8001.0
# 9355      9880.0
# 9356      9898.0
# 9357      8095.0
# 9358      7603.0
# 9359      7531.0
# 9360      9364.0
# 9361      8099.0
# 9362     11528.0
# 9363      9430.0
# 9364     10994.0
# 9365     11411.0
# 9366      8621.0
# 9367      9263.0
# 9368      8002.0
# 9369     10128.0
# 9370     10527.0
# 9371      7622.0
# 9372      9319.0
# 9373      8213.0
# 9374     10338.0
#
# [9375 rows x 41 columns]

# %%
file = "HR Data.xlsx"
df1 = pd.read_excel(file)

#Cleaning up the DOL field
df1['DOL'] = df1.DOL.apply(lambda x: 0 if x=='No' else 1 if x=='Yes' else 0 if x==0 else 1)

df1=df1.rename(columns={'Productivity%':'Productivity','Quality%':'Quality'})

y = df1['DOL']

X = df1.drop('DOL',axis=1)

d_accepted = joblib.load('column_vals.pkl')

d_supervisors = joblib.load('sup_dict.pkl')

processor = Pipeline([
                ('supervisor',Rate_Supervisor(d_supervisors)),
                ('designation',Split_Designation()),
                ('clients',Rate_Clients()),
                ('functionality',Split_Functionality()),
                ('age',Calc_Age()),
                ('districts',Add_District()),
                ('degree',Clean_HighestDegree()),
                ('leaves',Add_Leaves()),
                ('misc',Add_Vars()),
                ('feats',Keep_Features()),
                ('Impute_prod',Impute(X_train.Productivity.mean())),
                ('get_dummies',Dummy(d_accepted)),
                ('gbm',GradientBoostingClassifier(random_state=2,learning_rate=0.1,n_estimators=174,max_depth=8,
                                          min_samples_split=650,max_features =0.5,subsample = 0.95))
                ])

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4,random_state=2)

model = processor.fit(X_train,y_train)
pred = model.predict(X_test)
gbc_score_base = accuracy_score(pred,y_test)
print('Accuracy is: '+str(gbc_score_base))
# Out:
# C:\Users\amuth\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\amuth\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Accuracy is: 0.889066666667

# %%
joblib.dump(model,'model.pkl')
# Out:
# ['model.pkl']

# %%
joblib.dump(model,'pipeline.h5')
# Out:
# ['pipeline.h5']

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X,y,test_size=0.4,random_state=45)
pred2 = processor.predict(X_test2)
gbc_score_base2 = accuracy_score(pred2,y_test2)
print('Accuracy is: '+str(gbc_score_base2))
# Out:
# C:\Users\amuth\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\amuth\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Accuracy is: 0.904

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X,y,test_size=0.4,random_state=456)
test_pipe = joblib.load('model.pkl')
pred3 = test_pipe.predict(X_test2)
gbc_score_base3 = accuracy_score(pred3,y_test2)
print('Accuracy is: '+str(gbc_score_base3))
# Out:
# C:\Users\amuth\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\amuth\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Accuracy is: 0.9016

# %%
test_pipe = joblib.load('model.pkl')
pred3 = test_pipe.predict(X)
pred4 = pred3.tolist()
gbc_score_base3 = accuracy_score(pred3,y)
print('Accuracy is: '+str(gbc_score_base3))
# Out:
# Accuracy is: 0.8976

# %%
Emps = X.loc[0::,['Empcode']]
Emps['Prediction'] = pred4
Emps['Actual'] = y
print(Emps)
# Out:
#        Empcode  Prediction  Actual
# 0       C07383           0       0
# 1      F034899           0       0
# 2      E093441           0       0
# 3      D051008           1       1
# 4      F116696           1       1
# 5      G038672           0       0
# 6      F126884           1       1
# 7      F126978           1       1
# 8      F127004           0       0
# 9      D081399           1       1
# 10     E073222           0       0
# 11     E093453           0       0
# 12     F126918           0       0
# 13     F126753           1       1
# 14     F126979           0       0
# 15     G027530           0       0
# 16     F127009           0       0
# 17     F127012           0       0
# 18     E103756           0       0
# 19     E113937           1       1
# 20     G069683           1       1
# 21     F024683           0       1
# 22     E124186           0       0
# 23     G037810           0       0
# 24     G038257           1       1
# 25     G038423           0       0
# 26     G059359           0       0
# 27     G038431           1       1
# 28     G049177           0       1
# 29     G038723           0       0
# ...        ...         ...     ...
# 9345  H0212406           0       0
# 9346  H0212042           0       0
# 9347   F075749           0       0
# 9348   F085949           1       1
# 9349  H0212060           0       0
# 9350  H0212287           0       0
# 9351  H0312586           0       0
# 9352  H0312558           0       0
# 9353  H0312778           0       0
# 9354  H0111998           0       0
# 9355   F096206           0       0
# 9356   F096204           1       1
# 9357   F096210           1       1
# 9358  G1110854           0       0
# 9359  G1211140           0       0
# 9360  G1110834           0       0
# 9361  G1110930           0       0
# 9362   F024575           0       0
# 9363   F065391           0       0
# 9364   F065463           0       0
# 9365   F085993           1       1
# 9366  H0111795           1       1
# 9367  H0111583           0       0
# 9368  H0111881           0       0
# 9369  H0312530           0       0
# 9370  H0112008           0       0
# 9371  H0111655           0       0
# 9372  H0111557           0       1
# 9373  H0111961           0       0
# 9374  H0112010           0       0
#
# [9375 rows x 3 columns]
